# %% [markdown]
# ## Solve regional power flow with MLP load predictions
#
# 1. Define path to Master file corresponding to TGW year and scenario
# 2. Solve PF
# 3. Save lines and Xfer data
# 4. Optional: print network performance data

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Import packages

# %%
## Import packages
import time
import datetime
import os
import re
import json
import yaml
import joblib
import numpy as np 
import pandas as pd # to create data frames
import pyarrow as pa
import xarray as xr
import random
import matplotlib.pyplot as plt
import shutil #To enable duplicating files
from opendssdirect import dss
from src import physics_ops
from src import file_ops
from src import opendss_ops
from src import TGW_ops
from src import input_ops
from src import df_ops

# %% [markdown]
# ### Load config file with scenarios and parameters

# %%
config_file_name = 'opendss_config1'; config_path = f"/home/aviadf/opendss/notebooks/config/{config_file_name}.yaml"; config = input_ops.load_config(config_path)

enable_save = 1  # 1 enable | 0 disable

TGW_years_scenarios = config['TGW_years_scenarios']

demand_mode = config['demand_mode']
    
aggregation_level = config['aggregation_level']

CITY_REGIONS_TO_RUN = config['CITY_REGIONS_TO_RUN']

input_data_dict_name = config['input_data_dict_name']
aggregation_level = config['aggregation_level']
smart_ds_year = config['smart_ds_years'][0]
building_types = config["building_types"]

input_data_training_path = config['input_data_training_path']
CITY_REGIONS_TO_RUN = config['CITY_REGIONS_TO_RUN']
start_month = config['start_month']
end_month = config['end_month']

## Initialize parameters for saving paths
Y_column = config['Y_column']
input_data_prediction_path = config['input_data_prediction_path']
output_path_prediction_str = config['output_data_prediction_path']
output_pf_path = config['output_pf_path']

smart_ds_year = config['smart_ds_years'][0]
smart_ds_load_path = config['smart_ds_load_path'] + f"/{smart_ds_year}" # path to procesed smart-ds resstock data 
   
solution_mode = config['solution_mode']

## Define variables to create list of mdh to run
start_month_mdh = config['start_month_mdh'] 
end_month_mdh = config['end_month_mdh']
top_percent_mdh = config['top_percent_mdh']


## Load dictionary, sort by total city aggregated buildings demand, extract mdh of top % load hours
## load demand data 
regional_demand_weather_ampacity_path = smart_ds_load_path + f"/all_cities/aggregated_demand"
regional_demand_weather_ampacity_all_cities = joblib.load(os.path.join(regional_demand_weather_ampacity_path, "regional_demand_weather_ampacity_all_cities"))
## Sort your dictionary by aggregated total demand  
regional_demand_weather_ampacity_all_cities_sorted = df_ops.sort_nested_dict_dfs(regional_demand_weather_ampacity_all_cities, "aggregated_predicted_buildings_total_kw", ascending=False)
top_n_hours = int(np.ceil(8760*top_percent_mdh/100)) # calculate top city demand hours to run (top_percent_mdh% of hours of the year)
## Define start and end load hours to run
start_row_percent = config['start_row_percent']
start_row_idx = int(np.ceil(8760*start_row_percent/100)) # index from which to start loop of load hours
# start_row_idx = 0 # index from which to start loop of load hours
end_row_idx = top_n_hours 

# print(f"solution_mode: {solution_mode} \nCITY_REGIONS_TO_RUN: {CITY_REGIONS_TO_RUN} \n TGW year:{TGW_weather_year} \n TGW_scenario: {TGW_scenario} \n demand mode: {demand_mode}")
print(f"enable_save:{enable_save} \nsolution_mode: {solution_mode} \nTGW_years_scenarios:{TGW_years_scenarios} \nCITY_REGIONS_TO_RUN: {CITY_REGIONS_TO_RUN}  \n demand mode: {demand_mode}")

print(f"\n\ntop_percent_mdh: {top_percent_mdh}%, top_n_hours: {top_n_hours}, start_row_idx:{start_row_idx} ({start_row_percent}%), end_row_idx:{end_row_idx} ({top_percent_mdh}%) \n")
# Out:
# enable_save:1
# solution_mode: snapshot
# TGW_years_scenarios:{'2018': ['historical'], '2058': ['rcp45hotter']}
# CITY_REGIONS_TO_RUN: {'GSO': ['rural', 'industrial', 'urban-suburban'], 'AUS': ['P1R', 'P1U', 'P2U'], 'SFO': ['P1U', 'P2U', 'P1R']}
#  demand mode: MLP
#
#
# top_percent_mdh: 5%, top_n_hours: 438, start_row_idx:88 (1%), end_row_idx:438 (5%)

# %% [markdown]
# ## Run power flow
# Note: took 40min for all scenarios and 3 TGW year-scenario combinations

# %%
# Auxilary parameter 
pf_converged = 0 # defult value 0,  0 did not converge | 1 converged

master_file_option = 'TGW' # Options: TGW | default of smart-ds

# list_of_mdh = [(6,19,13)]  # list of mdh to run, e.g., GSO rural regional total kw peak

start_time = time.time()

for TGW_weather_year, TGW_scenarios in TGW_years_scenarios.items():
    for TGW_scenario in TGW_scenarios:
        print(f"--- Starting scenario: {TGW_weather_year} {TGW_scenario} ---\n")
        year = TGW_weather_year; 
        # --- Iterate over all selected regions --- 
        for city, regions in CITY_REGIONS_TO_RUN.items():
            
            ## create list of mdh for top % hours
            df_city = regional_demand_weather_ampacity_all_cities_sorted[(TGW_weather_year, TGW_scenario)][city]   # load regional demand data to later create list of mdh for top % hours  
            list_of_mdh = df_ops.get_top_n_mdh(df_city, top_n_hours, start_month_mdh, end_month_mdh)

            for region in regions:
                print(f"--- Starting scenario: {city} {region} ---\n")
                # --- Iterate over all selected month-day-hour (mdh) --- 
                for row_i in range(start_row_idx, end_row_idx):
                    mdh = list_of_mdh[row_i]; m,d,h = mdh
                    print(f"--- Starting Index: {row_i}, mdh: {mdh} ---\n")


                    # --- Initialize region's paths ---
                    # Create path to regional master file 
                    if solution_mode == 'snapshot':
                        region_path = f"/nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/{smart_ds_year}/{city}/{region}/scenarios/base_timeseries/opendss_no_loadshapes"
                    else:
                        region_path = f"/nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/{smart_ds_year}/{city}/{region}/scenarios/base_timeseries/opendss"  

                    # --- Redirect opendss to new master file  ---
                    # redirect_start_time = time.time()
                    dss.Basic.ClearAll() 

                    if master_file_option == 'TGW':
                        # --- Redirect opendss to TGW scenario master file  ---
                        new_master_dir = os.path.join(region_path, "predicted_master_files", TGW_scenario, TGW_weather_year)
                        dss.Command(f'Redirect "{new_master_dir}/Master_{TGW_scenario}_{TGW_weather_year}_{m}_{d}_{h}.dss"') # Direct opendss engine to master file 
                    else:
                        # --- Redirect opendss to default master file  ---
                        dss.Command(f'Redirect "{region_path}/Master.dss"') # Direct opendss engine to master file 

                    # redirect_end_time = time.time(); print(f"Compiled Master_{TGW_scenario}_{TGW_weather_year}_{m}_{d}_{h} in ", (redirect_end_time - redirect_start_time) / 60, "minutes")

                    # --- Solve power flow ---
                    pf_start_time = time.time()
                    dss.Solution.Solve()  # Solve the circuit
                    if dss.Solution.Converged():
                        print(f"---Power flow solution converged successfully after {dss.Solution.Iterations()} iterations---\n")
                        pf_converged = 1
                    else:
                        print("---Power flow solution did not converge!!!!!!!!!!!!!!!!!---\n")
                        pf_converged = 0
                    pf_end_time = time.time(); print("PF solve runtime:", (pf_end_time - pf_start_time) / 60, "minutes")

                    # --- Extract line and transformers data (physical properties, loading, voltage etc.) ---
                    dict_bus_coord = opendss_ops.create_dict_bus_coord(region_path)  # Create a dictionary of bus names and coordinates from Buscoords.dss
                    line_df = opendss_ops.extract_line_information(dict_bus_coord, year,m,d,h,row_i) # Extract line data
                    transformer_df = opendss_ops.extract_transformer_information(dict_bus_coord, year,m,d,h,row_i) # Extract transformers data

                    # Add current year line and xfer data to multi-year data frame
                    if row_i == start_row_idx:
                        all_line_df = line_df
                        all_transformer_df = transformer_df
                    else:
                        # concat current df to a multi-year data frame
                        all_line_df = pd.concat([all_line_df, line_df], ignore_index=True)
                        all_transformer_df = pd.concat([all_transformer_df, transformer_df], ignore_index=True) 

                # --- Save results per region---     
                if master_file_option == 'TGW':
                    lines_file_name = f"lines_top_{start_row_percent}_{top_percent_mdh}_percent"
                    transformers_file_name = f"transformers_top_{start_row_percent}_{top_percent_mdh}_percent"
                    metadata_file_name = f"metadata_top_{start_row_percent}_{top_percent_mdh}_percent"
                else:
                    lines_file_name = f"lines_regional_peak_default"
                    transformers_file_name = f"transformers_regional_peak_default"
                    metadata_file_name = f"metadata_regional_peak_default"
                    
                # Initialize dictionaries
                lines_dict = {}
                transformers_dict = {}
                # Initialize inner dictionary per TGW scenario
                lines_dict[(TGW_weather_year,TGW_scenario)] = {}
                transformers_dict[(TGW_weather_year,TGW_scenario)] = {}
                # Add data frames to 2 level key (smart-ds) of dictionaries
                lines_dict[(TGW_weather_year,TGW_scenario)][(smart_ds_year, city, region)] = all_line_df
                transformers_dict[(TGW_weather_year,TGW_scenario)][(smart_ds_year, city, region)] = all_transformer_df
                
                if enable_save == 1:
                    # Save dictionaries as joblib files
                    if master_file_option == 'TGW':
                        predictions_dir = os.path.join(output_pf_path, f"{city}/{region}/{TGW_scenario}/{TGW_weather_year}/")
                    else:
                        predictions_dir = os.path.join(output_pf_path, f"{city}/{region}/smart_ds_default/{smart_ds_year}")

                    os.makedirs(predictions_dir, exist_ok=True) # Create directories if they don't exist
                    
                    if pf_converged == 1: 
                        joblib.dump(lines_dict, os.path.join(predictions_dir, f"{lines_file_name}.joblib"))
                        joblib.dump(transformers_dict, os.path.join(predictions_dir, f"{transformers_file_name}.joblib"))
                    else:
                        joblib.dump(lines_dict, os.path.join(predictions_dir, f"{lines_file_name}_did_not_converge.joblib"))
                        joblib.dump(transformers_dict, os.path.join(predictions_dir, f"{transformers_file_name}_did_not_converge.joblib"))

                    # Define metadata #### !!! Add time array and temp array
                    timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
                    metadata = {
                        "changes": "demand_only",
                        "solution_mode": solution_mode,
                        "smart_ds_year": smart_ds_year,
                        "timestamp": timestamp,
                    }
                    # Save metadata to a JSON file
                    metadata_file = f"{predictions_dir}{metadata_file_name}.json"
                    with open(metadata_file, 'w') as f:
                        json.dump(metadata, f)
                    print(f"---- Results for scenario {city} {region} saved succesfuly in {predictions_dir} ----\n")
    
end_time = time.time(); print("Total runtime:", (end_time - start_time) / 60, "minutes")

# %% [markdown]
# ### Print bus voltages

# %%
buses = dss.Circuit.AllBusNames()
for bus in buses:
    dss.Circuit.SetActiveBus(bus)
    voltages = dss.Bus.puVmagAngle()
    voltages_pu = voltages[::2]
    for v in voltages_pu:
        if v < 0.9 or v > 1.1:
            print(f"Voltage warning at {bus}: {v:.3f} pu")
# Out:
# Voltage warning at p1rdt1577lv: 0.889 pu
# Voltage warning at p1rdt1577lv: 0.889 pu
# Voltage warning at p1rdt2214: 0.890 pu
# Voltage warning at p1rdt2214: 0.880 pu
# Voltage warning at p1rdt2214: 0.881 pu
# Voltage warning at p1rdt2214lv: 0.880 pu
# Voltage warning at p1rdt2214lv: 0.881 pu
# Voltage warning at p1rdt2215: 0.890 pu
# Voltage warning at p1rdt2215: 0.880 pu
# Voltage warning at p1rdt2215: 0.881 pu
# Voltage warning at p1rdt2215lv: 0.877 pu
# Voltage warning at p1rdt2215lv: 0.877 pu
# Voltage warning at p1rdt2216: 0.889 pu
# Voltage warning at p1rdt2216: 0.880 pu
# Voltage warning at p1rdt2216: 0.882 pu
# Voltage warning at p1rdt2216lv: 0.877 pu
# Voltage warning at p1rdt2216lv: 0.877 pu
# Voltage warning at p1rdt2217: 0.879 pu
# Voltage warning at p1rdt2217lv: 0.872 pu
# Voltage warning at p1rdt2217lv: 0.873 pu
# Voltage warning at p1rdt2218: 0.879 pu
# Voltage warning at p1rdt2218lv: 0.872 pu
# Voltage warning at p1rdt2218lv: 0.873 pu
# Voltage warning at p1rdt2219: 0.889 pu
# Voltage warning at p1rdt2219: 0.879 pu
# Voltage warning at p1rdt2219: 0.882 pu
# Voltage warning at p1rdt2219lv: 0.880 pu
# Voltage warning at p1rdt2219lv: 0.881 pu
# Voltage warning at p1rdt2220: 0.879 pu
# Voltage warning at p1rdt2220lv: 0.874 pu
# Voltage warning at p1rdt2220lv: 0.874 pu
# Voltage warning at p1rdt2221: 0.889 pu
# Voltage warning at p1rdt2221: 0.879 pu
# Voltage warning at p1rdt2221: 0.882 pu
# Voltage warning at p1rdt2221lv: 0.874 pu
# Voltage warning at p1rdt2221lv: 0.874 pu
# Voltage warning at p1rdt2841: 0.882 pu
# Voltage warning at p1rdt2841lv: 0.876 pu
# Voltage warning at p1rdt2841lv: 0.877 pu
# Voltage warning at p1rdt2842: 0.889 pu
# Voltage warning at p1rdt2842lv: 0.881 pu
# Voltage warning at p1rdt2842lv: 0.881 pu
# Voltage warning at p1rdt2844lv: 0.897 pu
# Voltage warning at p1rdt2844lv: 0.898 pu
# Voltage warning at p1rdt2846lv: 0.894 pu
# Voltage warning at p1rdt2846lv: 0.895 pu
# Voltage warning at p1rdt2847lv: 0.899 pu
# Voltage warning at p1rdt2847lv: 0.899 pu
# Voltage warning at p1rdt2850lv: 0.893 pu
# Voltage warning at p1rdt2850lv: 0.894 pu
# Voltage warning at p1rdt2873lv: 0.900 pu
# Voltage warning at p1rdt3162: 0.867 pu
# Voltage warning at p1rdt3162lv: 0.860 pu
# Voltage warning at p1rdt3162lv: 0.861 pu
# Voltage warning at p1rdt3163: 0.867 pu
# Voltage warning at p1rdt3163lv: 0.852 pu
# Voltage warning at p1rdt3163lv: 0.853 pu
# Voltage warning at p1rdt3164: 0.867 pu
# Voltage warning at p1rdt3164: 0.856 pu
# Voltage warning at p1rdt3164: 0.861 pu
# Voltage warning at p1rdt3164lv: 0.862 pu
# Voltage warning at p1rdt3164lv: 0.863 pu
# Voltage warning at p1rdt3165: 0.867 pu
# Voltage warning at p1rdt3165: 0.856 pu
# Voltage warning at p1rdt3165: 0.861 pu
# Voltage warning at p1rdt3165lv: 0.841 pu
# Voltage warning at p1rdt3165lv: 0.843 pu
# Voltage warning at p1rdt3166: 0.867 pu
# Voltage warning at p1rdt3166: 0.856 pu
# Voltage warning at p1rdt3166: 0.861 pu
# Voltage warning at p1rdt3166lv: 0.837 pu
# Voltage warning at p1rdt3166lv: 0.838 pu
# Voltage warning at p1rdt3167: 0.867 pu
# Voltage warning at p1rdt3167: 0.856 pu
# Voltage warning at p1rdt3167: 0.861 pu
# Voltage warning at p1rdt3167lv: 0.855 pu
# Voltage warning at p1rdt3167lv: 0.856 pu
# Voltage warning at p1rdt3168: 0.867 pu
# Voltage warning at p1rdt3168: 0.856 pu
# Voltage warning at p1rdt3168: 0.861 pu
# Voltage warning at p1rdt3168lv: 0.852 pu
# Voltage warning at p1rdt3168lv: 0.852 pu
# Voltage warning at p1rdt3169: 0.878 pu
# Voltage warning at p1rdt3169lv: 0.865 pu
# Voltage warning at p1rdt3169lv: 0.866 pu
# Voltage warning at p1rdt3170: 0.871 pu
# Voltage warning at p1rdt3170lv: 0.853 pu
# Voltage warning at p1rdt3170lv: 0.854 pu
# Voltage warning at p1rdt3171: 0.871 pu
# Voltage warning at p1rdt3171lv: 0.856 pu
# Voltage warning at p1rdt3171lv: 0.857 pu
# Voltage warning at p1rdt3172: 0.871 pu
# Voltage warning at p1rdt3172lv: 0.854 pu
# Voltage warning at p1rdt3172lv: 0.855 pu
# Voltage warning at p1rdt3173: 0.879 pu
# Voltage warning at p1rdt3173: 0.870 pu
# Voltage warning at p1rdt3173: 0.871 pu
# Voltage warning at p1rdt3173lv: 0.875 pu
# Voltage warning at p1rdt3173lv: 0.875 pu
# Voltage warning at p1rdt3174: 0.871 pu
# Voltage warning at p1rdt3174lv: 0.863 pu
# Voltage warning at p1rdt3174lv: 0.863 pu
# Voltage warning at p1rdt3175: 0.879 pu
# Voltage warning at p1rdt3175: 0.870 pu
# Voltage warning at p1rdt3175: 0.871 pu
# Voltage warning at p1rdt3175lv: 0.865 pu
# Voltage warning at p1rdt3175lv: 0.866 pu
# Voltage warning at p1rdt3176: 0.879 pu
# Voltage warning at p1rdt3176: 0.870 pu
# Voltage warning at p1rdt3176: 0.871 pu
# Voltage warning at p1rdt3176lv: 0.869 pu
# Voltage warning at p1rdt3176lv: 0.870 pu
# Voltage warning at p1rdt3177: 0.879 pu
# Voltage warning at p1rdt3177: 0.869 pu
# Voltage warning at p1rdt3177: 0.871 pu
# Voltage warning at p1rdt3177lv: 0.861 pu
# Voltage warning at p1rdt3177lv: 0.862 pu
# Voltage warning at p1rdt3178: 0.879 pu
# Voltage warning at p1rdt3178: 0.870 pu
# Voltage warning at p1rdt3178: 0.871 pu
# Voltage warning at p1rdt3178lv: 0.855 pu
# Voltage warning at p1rdt3178lv: 0.856 pu
# Voltage warning at p1rdt3179: 0.880 pu
# Voltage warning at p1rdt3179: 0.870 pu
# Voltage warning at p1rdt3179: 0.871 pu
# Voltage warning at p1rdt3179lv: 0.862 pu
# Voltage warning at p1rdt3179lv: 0.862 pu
# Voltage warning at p1rdt3180: 0.879 pu
# Voltage warning at p1rdt3180: 0.870 pu
# Voltage warning at p1rdt3180: 0.871 pu
# Voltage warning at p1rdt3180lv: 0.858 pu
# Voltage warning at p1rdt3180lv: 0.859 pu
# Voltage warning at p1rdt3181: 0.879 pu
# Voltage warning at p1rdt3181: 0.870 pu
# Voltage warning at p1rdt3181: 0.871 pu
# Voltage warning at p1rdt3181lv: 0.862 pu
# Voltage warning at p1rdt3181lv: 0.862 pu
# Voltage warning at p1rdt3182: 0.867 pu
# Voltage warning at p1rdt3182: 0.856 pu
# Voltage warning at p1rdt3182: 0.862 pu
# Voltage warning at p1rdt3182lv: 0.852 pu
# Voltage warning at p1rdt3182lv: 0.853 pu
# Voltage warning at p1rdt3183: 0.868 pu
# Voltage warning at p1rdt3183: 0.856 pu
# Voltage warning at p1rdt3183: 0.862 pu
# Voltage warning at p1rdt3183lv: 0.843 pu
# Voltage warning at p1rdt3183lv: 0.844 pu
# Voltage warning at p1rdt3184: 0.867 pu
# Voltage warning at p1rdt3184: 0.856 pu
# Voltage warning at p1rdt3184: 0.861 pu
# Voltage warning at p1rdt3184lv: 0.859 pu
# Voltage warning at p1rdt3184lv: 0.848 pu
# Voltage warning at p1rdt3184lv: 0.854 pu
# Voltage warning at p1rdt3185: 0.867 pu
# Voltage warning at p1rdt3185: 0.856 pu
# Voltage warning at p1rdt3185: 0.861 pu
# Voltage warning at p1rdt3185lv: 0.853 pu
# Voltage warning at p1rdt3185lv: 0.842 pu
# Voltage warning at p1rdt3185lv: 0.847 pu
# Voltage warning at p1rdt3186: 0.867 pu
# Voltage warning at p1rdt3186: 0.856 pu
# Voltage warning at p1rdt3186: 0.861 pu
# Voltage warning at p1rdt3186lv: 0.843 pu
# Voltage warning at p1rdt3186lv: 0.844 pu
# Voltage warning at p1rdt3187: 0.867 pu
# Voltage warning at p1rdt3187: 0.856 pu
# Voltage warning at p1rdt3187: 0.862 pu
# Voltage warning at p1rdt3187lv: 0.855 pu
# Voltage warning at p1rdt3187lv: 0.856 pu
# Voltage warning at p1rdt3188: 0.868 pu
# Voltage warning at p1rdt3188: 0.856 pu
# Voltage warning at p1rdt3188: 0.862 pu
# Voltage warning at p1rdt3188lv: 0.845 pu
# Voltage warning at p1rdt3188lv: 0.847 pu
# Voltage warning at p1rdt3189: 0.867 pu
# Voltage warning at p1rdt3189: 0.856 pu
# Voltage warning at p1rdt3189: 0.861 pu
# Voltage warning at p1rdt3189lv: 0.858 pu
# Voltage warning at p1rdt3189lv: 0.859 pu
# Voltage warning at p1rdt3190: 0.868 pu
# Voltage warning at p1rdt3190: 0.857 pu
# Voltage warning at p1rdt3190: 0.862 pu
# Voltage warning at p1rdt3190lv: 0.850 pu
# Voltage warning at p1rdt3190lv: 0.850 pu
# Voltage warning at p1rdt3191: 0.868 pu
# Voltage warning at p1rdt3191: 0.857 pu
# Voltage warning at p1rdt3191: 0.862 pu
# Voltage warning at p1rdt3191lv: 0.838 pu
# Voltage warning at p1rdt3191lv: 0.840 pu
# Voltage warning at p1rdt3192: 0.867 pu
# Voltage warning at p1rdt3192: 0.856 pu
# Voltage warning at p1rdt3192: 0.861 pu
# Voltage warning at p1rdt3192lv: 0.864 pu
# Voltage warning at p1rdt3192lv: 0.865 pu
# Voltage warning at p1rdt3193: 0.867 pu
# Voltage warning at p1rdt3193: 0.856 pu
# Voltage warning at p1rdt3193: 0.861 pu
# Voltage warning at p1rdt3193lv: 0.851 pu
# Voltage warning at p1rdt3193lv: 0.840 pu
# Voltage warning at p1rdt3193lv: 0.845 pu
# Voltage warning at p1rdt3194: 0.867 pu
# Voltage warning at p1rdt3194: 0.856 pu
# Voltage warning at p1rdt3194: 0.862 pu
# Voltage warning at p1rdt3194lv: 0.859 pu
# Voltage warning at p1rdt3194lv: 0.860 pu
# Voltage warning at p1rdt3195: 0.861 pu
# Voltage warning at p1rdt3195lv: 0.855 pu
# Voltage warning at p1rdt3195lv: 0.855 pu
# Voltage warning at p1rdt3196: 0.870 pu
# Voltage warning at p1rdt3196lv: 0.864 pu
# Voltage warning at p1rdt3196lv: 0.864 pu
# Voltage warning at p1rdt3197: 0.866 pu
# Voltage warning at p1rdt3197: 0.855 pu
# Voltage warning at p1rdt3197: 0.861 pu
# Voltage warning at p1rdt3197lv: 0.842 pu
# Voltage warning at p1rdt3197lv: 0.830 pu
# Voltage warning at p1rdt3197lv: 0.836 pu
# Voltage warning at p1rdt3198: 0.866 pu
# Voltage warning at p1rdt3198: 0.855 pu
# Voltage warning at p1rdt3198: 0.861 pu
# Voltage warning at p1rdt3198lv: 0.851 pu
# Voltage warning at p1rdt3198lv: 0.840 pu
# Voltage warning at p1rdt3198lv: 0.846 pu
# Voltage warning at p1rdt3199: 0.861 pu
# Voltage warning at p1rdt3199lv: 0.854 pu
# Voltage warning at p1rdt3199lv: 0.854 pu
# Voltage warning at p1rdt3200: 0.868 pu
# Voltage warning at p1rdt3200: 0.857 pu
# Voltage warning at p1rdt3200: 0.862 pu
# Voltage warning at p1rdt3200lv: 0.857 pu
# Voltage warning at p1rdt3200lv: 0.846 pu
# Voltage warning at p1rdt3200lv: 0.851 pu
# Voltage warning at p1rdt3201: 0.868 pu
# Voltage warning at p1rdt3201: 0.857 pu
# Voltage warning at p1rdt3201: 0.862 pu
# Voltage warning at p1rdt3201lv: 0.860 pu
# Voltage warning at p1rdt3201lv: 0.861 pu
# Voltage warning at p1rdt3202: 0.869 pu
# Voltage warning at p1rdt3202: 0.857 pu
# Voltage warning at p1rdt3202: 0.862 pu
# Voltage warning at p1rdt3202lv: 0.856 pu
# Voltage warning at p1rdt3202lv: 0.858 pu
# Voltage warning at p1rdt3203: 0.873 pu
# Voltage warning at p1rdt3203lv: 0.863 pu
# Voltage warning at p1rdt3203lv: 0.863 pu
# Voltage warning at p1rdt3204: 0.873 pu
# Voltage warning at p1rdt3204lv: 0.865 pu
# Voltage warning at p1rdt3204lv: 0.865 pu
# Voltage warning at p1rdt3205: 0.880 pu
# Voltage warning at p1rdt3205lv: 0.871 pu
# Voltage warning at p1rdt3205lv: 0.872 pu
# Voltage warning at p1rdt3206: 0.880 pu
# Voltage warning at p1rdt3206lv: 0.870 pu
# Voltage warning at p1rdt3206lv: 0.871 pu
# Voltage warning at p1rdt3207: 0.880 pu
# Voltage warning at p1rdt3207lv: 0.875 pu
# Voltage warning at p1rdt3207lv: 0.876 pu
# Voltage warning at p1rdt3208: 0.880 pu
# Voltage warning at p1rdt3208lv: 0.874 pu
# Voltage warning at p1rdt3208lv: 0.874 pu
# Voltage warning at p1rdt3209: 0.880 pu
# Voltage warning at p1rdt3209lv: 0.872 pu
# Voltage warning at p1rdt3209lv: 0.873 pu
# Voltage warning at p1rdt3213: 0.880 pu
# Voltage warning at p1rdt3213lv: 0.869 pu
# Voltage warning at p1rdt3213lv: 0.870 pu
# Voltage warning at p1rdt3214: 0.880 pu
# Voltage warning at p1rdt3214lv: 0.873 pu
# Voltage warning at p1rdt3214lv: 0.873 pu
# Voltage warning at p1rdt3215: 0.881 pu
# Voltage warning at p1rdt3215lv: 0.875 pu
# Voltage warning at p1rdt3215lv: 0.875 pu
# Voltage warning at p1rdt3216: 0.881 pu
# Voltage warning at p1rdt3216lv: 0.872 pu
# Voltage warning at p1rdt3216lv: 0.872 pu
# Voltage warning at p1rdt3217: 0.870 pu
# Voltage warning at p1rdt3217lv: 0.859 pu
# Voltage warning at p1rdt3217lv: 0.860 pu
# Voltage warning at p1rdt3218: 0.870 pu
# Voltage warning at p1rdt3218lv: 0.862 pu
# Voltage warning at p1rdt3218lv: 0.862 pu
# Voltage warning at p1rdt3219: 0.870 pu
# Voltage warning at p1rdt3219lv: 0.855 pu
# Voltage warning at p1rdt3219lv: 0.856 pu
# Voltage warning at p1rdt3220: 0.870 pu
# Voltage warning at p1rdt3220lv: 0.865 pu
# Voltage warning at p1rdt3220lv: 0.865 pu
# Voltage warning at p1rdt3228: 0.861 pu
# Voltage warning at p1rdt3228lv: 0.843 pu
# Voltage warning at p1rdt3228lv: 0.844 pu
# Voltage warning at p1rdt3229: 0.861 pu
# Voltage warning at p1rdt3229lv: 0.854 pu
# Voltage warning at p1rdt3229lv: 0.855 pu
# Voltage warning at p1rdt3230: 0.856 pu
# Voltage warning at p1rdt3230lv: 0.848 pu
# Voltage warning at p1rdt3230lv: 0.848 pu
# Voltage warning at p1rdt3231: 0.855 pu
# Voltage warning at p1rdt3231lv: 0.848 pu
# Voltage warning at p1rdt3231lv: 0.848 pu
# Voltage warning at p1rdt3232: 0.867 pu
# Voltage warning at p1rdt3232: 0.856 pu
# Voltage warning at p1rdt3232: 0.861 pu
# Voltage warning at p1rdt3232lv: 0.845 pu
# Voltage warning at p1rdt3232lv: 0.846 pu
# Voltage warning at p1rdt3233: 0.856 pu
# Voltage warning at p1rdt3233lv: 0.842 pu
# Voltage warning at p1rdt3233lv: 0.843 pu
# Voltage warning at p1rdt3234: 0.856 pu
# Voltage warning at p1rdt3234lv: 0.852 pu
# Voltage warning at p1rdt3234lv: 0.852 pu
# Voltage warning at p1rdt3258: 0.866 pu
# Voltage warning at p1rdt3258: 0.855 pu
# Voltage warning at p1rdt3258: 0.861 pu
# Voltage warning at p1rdt3258lv: 0.857 pu
# Voltage warning at p1rdt3258lv: 0.846 pu
# Voltage warning at p1rdt3258lv: 0.851 pu
# Voltage warning at p1rdt3259: 0.866 pu
# Voltage warning at p1rdt3259: 0.855 pu
# Voltage warning at p1rdt3259: 0.861 pu
# Voltage warning at p1rdt3259lv: 0.846 pu
# Voltage warning at p1rdt3259lv: 0.834 pu
# Voltage warning at p1rdt3259lv: 0.840 pu
# Voltage warning at p1rdt3260: 0.866 pu
# Voltage warning at p1rdt3260: 0.855 pu
# Voltage warning at p1rdt3260: 0.861 pu
# Voltage warning at p1rdt3260lv: 0.851 pu
# Voltage warning at p1rdt3260lv: 0.839 pu
# Voltage warning at p1rdt3260lv: 0.845 pu
# Voltage warning at p1rdt3261: 0.861 pu
# Voltage warning at p1rdt3261lv: 0.855 pu
# Voltage warning at p1rdt3261lv: 0.855 pu
# Voltage warning at p1rdt3262: 0.866 pu
# Voltage warning at p1rdt3262lv: 0.857 pu
# Voltage warning at p1rdt3262lv: 0.858 pu
# Voltage warning at p1rdt3263: 0.870 pu
# Voltage warning at p1rdt3263lv: 0.867 pu
# Voltage warning at p1rdt3263lv: 0.867 pu
# Voltage warning at p1rdt3264: 0.866 pu
# Voltage warning at p1rdt3264: 0.855 pu
# Voltage warning at p1rdt3264: 0.861 pu
# Voltage warning at p1rdt3264lv: 0.851 pu
# Voltage warning at p1rdt3264lv: 0.840 pu
# Voltage warning at p1rdt3264lv: 0.845 pu
# Voltage warning at p1rdt3265: 0.866 pu
# Voltage warning at p1rdt3265: 0.855 pu
# Voltage warning at p1rdt3265: 0.861 pu
# Voltage warning at p1rdt3265lv: 0.845 pu
# Voltage warning at p1rdt3265lv: 0.846 pu
# Voltage warning at p1rdt3266: 0.866 pu
# Voltage warning at p1rdt3266: 0.855 pu
# Voltage warning at p1rdt3266: 0.861 pu
# Voltage warning at p1rdt3266lv: 0.858 pu
# Voltage warning at p1rdt3266lv: 0.858 pu
# Voltage warning at p1rdt3267: 0.866 pu
# Voltage warning at p1rdt3267: 0.855 pu
# Voltage warning at p1rdt3267: 0.861 pu
# Voltage warning at p1rdt3267lv: 0.844 pu
# Voltage warning at p1rdt3267lv: 0.845 pu
# Voltage warning at p1rdt3268: 0.867 pu
# Voltage warning at p1rdt3268: 0.856 pu
# Voltage warning at p1rdt3268: 0.861 pu
# Voltage warning at p1rdt3268lv: 0.852 pu
# Voltage warning at p1rdt3268lv: 0.841 pu
# Voltage warning at p1rdt3268lv: 0.846 pu
# Voltage warning at p1rdt3269: 0.867 pu
# Voltage warning at p1rdt3269: 0.856 pu
# Voltage warning at p1rdt3269: 0.861 pu
# Voltage warning at p1rdt3269lv: 0.859 pu
# Voltage warning at p1rdt3269lv: 0.859 pu
# Voltage warning at p1rdt3270: 0.867 pu
# Voltage warning at p1rdt3270: 0.856 pu
# Voltage warning at p1rdt3270: 0.861 pu
# Voltage warning at p1rdt3270lv: 0.857 pu
# Voltage warning at p1rdt3270lv: 0.845 pu
# Voltage warning at p1rdt3270lv: 0.851 pu
# Voltage warning at p1rdt3288: 0.861 pu
# Voltage warning at p1rdt3288lv: 0.847 pu
# Voltage warning at p1rdt3288lv: 0.848 pu
# Voltage warning at p1rdt3289: 0.861 pu
# Voltage warning at p1rdt3289lv: 0.852 pu
# Voltage warning at p1rdt3289lv: 0.852 pu
# Voltage warning at p1rdt3290: 0.861 pu
# Voltage warning at p1rdt3290lv: 0.842 pu
# Voltage warning at p1rdt3290lv: 0.843 pu
# Voltage warning at p1rdt3291: 0.867 pu
# Voltage warning at p1rdt3291: 0.856 pu
# Voltage warning at p1rdt3291: 0.861 pu
# Voltage warning at p1rdt3291lv: 0.849 pu
# Voltage warning at p1rdt3291lv: 0.851 pu
# Voltage warning at p1rdt3384: 0.857 pu
# Voltage warning at p1rdt3384lv: 0.849 pu
# Voltage warning at p1rdt3384lv: 0.849 pu
# Voltage warning at p1rdt3385: 0.869 pu
# Voltage warning at p1rdt3385: 0.858 pu
# Voltage warning at p1rdt3385: 0.863 pu
# Voltage warning at p1rdt3385lv: 0.852 pu
# Voltage warning at p1rdt3385lv: 0.853 pu
# Voltage warning at p1rdt3386: 0.870 pu
# Voltage warning at p1rdt3386: 0.859 pu
# Voltage warning at p1rdt3386: 0.863 pu
# Voltage warning at p1rdt3386lv: 0.854 pu
# Voltage warning at p1rdt3386lv: 0.855 pu
# Voltage warning at p1rdt3387: 0.870 pu
# Voltage warning at p1rdt3387: 0.859 pu
# Voltage warning at p1rdt3387: 0.863 pu
# Voltage warning at p1rdt3387lv: 0.861 pu
# Voltage warning at p1rdt3387lv: 0.850 pu
# Voltage warning at p1rdt3387lv: 0.854 pu
# Voltage warning at p1rdt3388: 0.870 pu
# Voltage warning at p1rdt3388: 0.859 pu
# Voltage warning at p1rdt3388: 0.863 pu
# Voltage warning at p1rdt3388lv: 0.858 pu
# Voltage warning at p1rdt3388lv: 0.860 pu
# Voltage warning at p1rdt3389: 0.871 pu
# Voltage warning at p1rdt3389: 0.860 pu
# Voltage warning at p1rdt3389: 0.864 pu
# Voltage warning at p1rdt3389lv: 0.849 pu
# Voltage warning at p1rdt3389lv: 0.849 pu
# Voltage warning at p1rdt3390: 0.870 pu
# Voltage warning at p1rdt3390lv: 0.866 pu
# Voltage warning at p1rdt3390lv: 0.866 pu
# Voltage warning at p1rdt3391: 0.870 pu
# Voltage warning at p1rdt3391lv: 0.865 pu
# Voltage warning at p1rdt3391lv: 0.865 pu
# Voltage warning at p1rdt3392: 0.870 pu
# Voltage warning at p1rdt3392lv: 0.865 pu
# Voltage warning at p1rdt3392lv: 0.865 pu
# Voltage warning at p1rdt3393: 0.871 pu
# Voltage warning at p1rdt3393lv: 0.848 pu
# Voltage warning at p1rdt3393lv: 0.849 pu
# Voltage warning at p1rdt3394: 0.882 pu
# Voltage warning at p1rdt3394lv: 0.875 pu
# Voltage warning at p1rdt3394lv: 0.876 pu
# Voltage warning at p1rdt3395: 0.871 pu
# Voltage warning at p1rdt3395lv: 0.867 pu
# Voltage warning at p1rdt3395lv: 0.868 pu
# Voltage warning at p1rdt3396: 0.882 pu
# Voltage warning at p1rdt3396: 0.872 pu
# Voltage warning at p1rdt3396: 0.874 pu
# Voltage warning at p1rdt3396lv: 0.865 pu
# Voltage warning at p1rdt3396lv: 0.865 pu
# Voltage warning at p1rdt3397: 0.882 pu
# Voltage warning at p1rdt3397: 0.872 pu
# Voltage warning at p1rdt3397: 0.874 pu
# Voltage warning at p1rdt3397lv: 0.875 pu
# Voltage warning at p1rdt3397lv: 0.875 pu
# Voltage warning at p1rdt3398: 0.882 pu
# Voltage warning at p1rdt3398: 0.872 pu
# Voltage warning at p1rdt3398: 0.874 pu
# Voltage warning at p1rdt3398lv: 0.865 pu
# Voltage warning at p1rdt3398lv: 0.866 pu
# Voltage warning at p1rdt3399: 0.862 pu
# Voltage warning at p1rdt3399lv: 0.850 pu
# Voltage warning at p1rdt3399lv: 0.852 pu
# Voltage warning at p1rdt3400: 0.862 pu
# Voltage warning at p1rdt3400lv: 0.846 pu
# Voltage warning at p1rdt3400lv: 0.846 pu
# Voltage warning at p1rdt3401: 0.863 pu
# Voltage warning at p1rdt3401lv: 0.852 pu
# Voltage warning at p1rdt3401lv: 0.853 pu
# Voltage warning at p1rdt3402: 0.863 pu
# Voltage warning at p1rdt3402lv: 0.842 pu
# Voltage warning at p1rdt3402lv: 0.845 pu
# Voltage warning at p1rdt3403: 0.874 pu
# Voltage warning at p1rdt3403: 0.863 pu
# Voltage warning at p1rdt3403: 0.866 pu
# Voltage warning at p1rdt3403lv: 0.863 pu
# Voltage warning at p1rdt3403lv: 0.865 pu
# Voltage warning at p1rdt3404: 0.873 pu
# Voltage warning at p1rdt3404: 0.862 pu
# Voltage warning at p1rdt3404: 0.865 pu
# Voltage warning at p1rdt3404lv: 0.858 pu
# Voltage warning at p1rdt3404lv: 0.859 pu
# Voltage warning at p1rdt3405: 0.874 pu
# Voltage warning at p1rdt3405: 0.863 pu
# Voltage warning at p1rdt3405: 0.866 pu
# Voltage warning at p1rdt3405lv: 0.853 pu
# Voltage warning at p1rdt3405lv: 0.854 pu
# Voltage warning at p1rdt3406: 0.875 pu
# Voltage warning at p1rdt3406: 0.864 pu
# Voltage warning at p1rdt3406: 0.867 pu
# Voltage warning at p1rdt3406lv: 0.864 pu
# Voltage warning at p1rdt3406lv: 0.865 pu
# Voltage warning at p1rdt3407: 0.875 pu
# Voltage warning at p1rdt3407: 0.865 pu
# Voltage warning at p1rdt3407: 0.867 pu
# Voltage warning at p1rdt3407lv: 0.853 pu
# Voltage warning at p1rdt3407lv: 0.856 pu
# Voltage warning at p1rdt3408: 0.876 pu
# Voltage warning at p1rdt3408: 0.866 pu
# Voltage warning at p1rdt3408: 0.868 pu
# Voltage warning at p1rdt3408lv: 0.863 pu
# Voltage warning at p1rdt3408lv: 0.864 pu
# Voltage warning at p1rdt3409: 0.867 pu
# Voltage warning at p1rdt3409lv: 0.855 pu
# Voltage warning at p1rdt3409lv: 0.857 pu
# Voltage warning at p1rdt3410: 0.867 pu
# Voltage warning at p1rdt3410lv: 0.854 pu
# Voltage warning at p1rdt3410lv: 0.855 pu
# Voltage warning at p1rdt3411: 0.878 pu
# Voltage warning at p1rdt3411lv: 0.868 pu
# Voltage warning at p1rdt3411lv: 0.869 pu
# Voltage warning at p1rdt3412: 0.878 pu
# Voltage warning at p1rdt3412lv: 0.860 pu
# Voltage warning at p1rdt3412lv: 0.861 pu
# Voltage warning at p1rdt3413: 0.868 pu
# Voltage warning at p1rdt3413lv: 0.862 pu
# Voltage warning at p1rdt3413lv: 0.863 pu
# Voltage warning at p1rdt3414: 0.868 pu
# Voltage warning at p1rdt3414lv: 0.859 pu
# Voltage warning at p1rdt3414lv: 0.860 pu
# Voltage warning at p1rdt3415: 0.877 pu
# Voltage warning at p1rdt3415: 0.867 pu
# Voltage warning at p1rdt3415: 0.869 pu
# Voltage warning at p1rdt3415lv: 0.862 pu
# Voltage warning at p1rdt3415lv: 0.863 pu
# Voltage warning at p1rdt3416: 0.879 pu
# Voltage warning at p1rdt3416: 0.869 pu
# Voltage warning at p1rdt3416: 0.871 pu
# Voltage warning at p1rdt3416lv: 0.855 pu
# Voltage warning at p1rdt3416lv: 0.857 pu
# Voltage warning at p1rdt3417: 0.879 pu
# Voltage warning at p1rdt3417: 0.869 pu
# Voltage warning at p1rdt3417: 0.870 pu
# Voltage warning at p1rdt3417lv: 0.853 pu
# Voltage warning at p1rdt3417lv: 0.854 pu
# Voltage warning at p1rdt3418: 0.879 pu
# Voltage warning at p1rdt3418: 0.869 pu
# Voltage warning at p1rdt3418: 0.870 pu
# Voltage warning at p1rdt3418lv: 0.860 pu
# Voltage warning at p1rdt3418lv: 0.861 pu
# Voltage warning at p1rdt3419: 0.879 pu
# Voltage warning at p1rdt3419: 0.869 pu
# Voltage warning at p1rdt3419: 0.870 pu
# Voltage warning at p1rdt3419lv: 0.854 pu
# Voltage warning at p1rdt3419lv: 0.855 pu
# Voltage warning at p1rdt3420: 0.879 pu
# Voltage warning at p1rdt3420: 0.869 pu
# Voltage warning at p1rdt3420: 0.870 pu
# Voltage warning at p1rdt3420lv: 0.847 pu
# Voltage warning at p1rdt3420lv: 0.848 pu
# Voltage warning at p1rdt3421: 0.878 pu
# Voltage warning at p1rdt3421lv: 0.866 pu
# Voltage warning at p1rdt3421lv: 0.867 pu
# Voltage warning at p1rdt3422: 0.878 pu
# Voltage warning at p1rdt3422lv: 0.866 pu
# Voltage warning at p1rdt3422lv: 0.867 pu
# Voltage warning at p1rdt3423: 0.878 pu
# Voltage warning at p1rdt3423lv: 0.867 pu
# Voltage warning at p1rdt3423lv: 0.868 pu
# Voltage warning at p1rdt3424: 0.878 pu
# Voltage warning at p1rdt3424lv: 0.863 pu
# Voltage warning at p1rdt3424lv: 0.864 pu
# Voltage warning at p1rdt3425: 0.874 pu
# Voltage warning at p1rdt3425lv: 0.865 pu
# Voltage warning at p1rdt3425lv: 0.866 pu
# Voltage warning at p1rdt3426: 0.878 pu
# Voltage warning at p1rdt3426lv: 0.869 pu
# Voltage warning at p1rdt3426lv: 0.870 pu
# Voltage warning at p1rdt3427: 0.883 pu
# Voltage warning at p1rdt3427: 0.873 pu
# Voltage warning at p1rdt3427: 0.875 pu
# Voltage warning at p1rdt3427lv: 0.874 pu
# Voltage warning at p1rdt3427lv: 0.875 pu
# Voltage warning at p1rdt3428: 0.883 pu
# Voltage warning at p1rdt3428: 0.873 pu
# Voltage warning at p1rdt3428: 0.874 pu
# Voltage warning at p1rdt3428lv: 0.869 pu
# Voltage warning at p1rdt3428lv: 0.870 pu
# Voltage warning at p1rdt3429: 0.883 pu
# Voltage warning at p1rdt3429: 0.873 pu
# Voltage warning at p1rdt3429: 0.875 pu
# Voltage warning at p1rdt3429lv: 0.859 pu
# Voltage warning at p1rdt3429lv: 0.860 pu
# Voltage warning at p1rdt3430: 0.878 pu
# Voltage warning at p1rdt3430lv: 0.867 pu
# Voltage warning at p1rdt3430lv: 0.868 pu
# Voltage warning at p1rdt3431: 0.878 pu
# Voltage warning at p1rdt3431lv: 0.872 pu
# Voltage warning at p1rdt3431lv: 0.872 pu
# Voltage warning at p1rdt3432: 0.879 pu
# Voltage warning at p1rdt3432: 0.869 pu
# Voltage warning at p1rdt3432: 0.870 pu
# Voltage warning at p1rdt3432lv: 0.857 pu
# Voltage warning at p1rdt3432lv: 0.858 pu
# Voltage warning at p1rdt3433: 0.869 pu
# Voltage warning at p1rdt3433lv: 0.863 pu
# Voltage warning at p1rdt3433lv: 0.864 pu
# Voltage warning at p1rdt3434: 0.868 pu
# Voltage warning at p1rdt3434lv: 0.860 pu
# Voltage warning at p1rdt3434lv: 0.861 pu
# Voltage warning at p1rdt3435: 0.868 pu
# Voltage warning at p1rdt3435lv: 0.852 pu
# Voltage warning at p1rdt3435lv: 0.853 pu
# Voltage warning at p1rdt3436: 0.884 pu
# Voltage warning at p1rdt3436: 0.874 pu
# Voltage warning at p1rdt3436: 0.875 pu
# Voltage warning at p1rdt3436lv: 0.869 pu
# Voltage warning at p1rdt3436lv: 0.870 pu
# Voltage warning at p1rdt3437: 0.884 pu
# Voltage warning at p1rdt3437: 0.874 pu
# Voltage warning at p1rdt3437: 0.875 pu
# Voltage warning at p1rdt3437lv: 0.863 pu
# Voltage warning at p1rdt3437lv: 0.864 pu
# Voltage warning at p1rdt3438: 0.868 pu
# Voltage warning at p1rdt3438lv: 0.857 pu
# Voltage warning at p1rdt3438lv: 0.858 pu
# Voltage warning at p1rdt3439: 0.879 pu
# Voltage warning at p1rdt3439: 0.869 pu
# Voltage warning at p1rdt3439: 0.870 pu
# Voltage warning at p1rdt3439lv: 0.860 pu
# Voltage warning at p1rdt3439lv: 0.860 pu
# Voltage warning at p1rdt3440: 0.870 pu
# Voltage warning at p1rdt3440lv: 0.853 pu
# Voltage warning at p1rdt3440lv: 0.855 pu
# Voltage warning at p1rdt3441: 0.884 pu
# Voltage warning at p1rdt3441: 0.874 pu
# Voltage warning at p1rdt3441: 0.876 pu
# Voltage warning at p1rdt3441lv: 0.875 pu
# Voltage warning at p1rdt3441lv: 0.876 pu
# Voltage warning at p1rdt3442: 0.879 pu
# Voltage warning at p1rdt3442: 0.869 pu
# Voltage warning at p1rdt3442: 0.871 pu
# Voltage warning at p1rdt3442lv: 0.862 pu
# Voltage warning at p1rdt3442lv: 0.863 pu
# Voltage warning at p1rdt3443: 0.871 pu
# Voltage warning at p1rdt3443lv: 0.862 pu
# Voltage warning at p1rdt3443lv: 0.863 pu
# Voltage warning at p1rdt3444: 0.871 pu
# Voltage warning at p1rdt3444lv: 0.859 pu
# Voltage warning at p1rdt3444lv: 0.860 pu
# Voltage warning at p1rdt3445: 0.871 pu
# Voltage warning at p1rdt3445lv: 0.861 pu
# Voltage warning at p1rdt3445lv: 0.861 pu
# Voltage warning at p1rdt3446: 0.881 pu
# Voltage warning at p1rdt3446: 0.871 pu
# Voltage warning at p1rdt3446: 0.873 pu
# Voltage warning at p1rdt3446lv: 0.858 pu
# Voltage warning at p1rdt3446lv: 0.858 pu
# Voltage warning at p1rdt3447: 0.881 pu
# Voltage warning at p1rdt3447: 0.871 pu
# Voltage warning at p1rdt3447: 0.873 pu
# Voltage warning at p1rdt3447lv: 0.869 pu
# Voltage warning at p1rdt3447lv: 0.871 pu
# Voltage warning at p1rdt3448: 0.881 pu
# Voltage warning at p1rdt3448: 0.871 pu
# Voltage warning at p1rdt3448: 0.872 pu
# Voltage warning at p1rdt3448lv: 0.859 pu
# Voltage warning at p1rdt3448lv: 0.859 pu
# Voltage warning at p1rdt3449: 0.881 pu
# Voltage warning at p1rdt3449: 0.871 pu
# Voltage warning at p1rdt3449: 0.872 pu
# Voltage warning at p1rdt3449lv: 0.868 pu
# Voltage warning at p1rdt3449lv: 0.868 pu
# Voltage warning at p1rdt3450: 0.881 pu
# Voltage warning at p1rdt3450: 0.870 pu
# Voltage warning at p1rdt3450: 0.872 pu
# Voltage warning at p1rdt3450lv: 0.864 pu
# Voltage warning at p1rdt3450lv: 0.865 pu
# Voltage warning at p1rdt3451: 0.881 pu
# Voltage warning at p1rdt3451: 0.871 pu
# Voltage warning at p1rdt3451: 0.872 pu
# Voltage warning at p1rdt3451lv: 0.864 pu
# Voltage warning at p1rdt3451lv: 0.865 pu
# Voltage warning at p1rdt3452: 0.880 pu
# Voltage warning at p1rdt3452: 0.870 pu
# Voltage warning at p1rdt3452: 0.872 pu
# Voltage warning at p1rdt3452lv: 0.864 pu
# Voltage warning at p1rdt3452lv: 0.865 pu
# Voltage warning at p1rdt3453: 0.880 pu
# Voltage warning at p1rdt3453: 0.870 pu
# Voltage warning at p1rdt3453: 0.872 pu
# Voltage warning at p1rdt3453lv: 0.865 pu
# Voltage warning at p1rdt3453lv: 0.866 pu
# Voltage warning at p1rdt3454: 0.880 pu
# Voltage warning at p1rdt3454: 0.870 pu
# Voltage warning at p1rdt3454: 0.872 pu
# Voltage warning at p1rdt3454lv: 0.863 pu
# Voltage warning at p1rdt3454lv: 0.864 pu
# Voltage warning at p1rdt3455: 0.870 pu
# Voltage warning at p1rdt3455lv: 0.862 pu
# Voltage warning at p1rdt3455lv: 0.863 pu
# Voltage warning at p1rdt3456: 0.868 pu
# Voltage warning at p1rdt3456lv: 0.860 pu
# Voltage warning at p1rdt3456lv: 0.860 pu
# Voltage warning at p1rdt3457: 0.880 pu
# Voltage warning at p1rdt3457: 0.870 pu
# Voltage warning at p1rdt3457: 0.872 pu
# Voltage warning at p1rdt3457lv: 0.863 pu
# Voltage warning at p1rdt3457lv: 0.864 pu
# Voltage warning at p1rdt3458: 0.877 pu
# Voltage warning at p1rdt3458lv: 0.864 pu
# Voltage warning at p1rdt3458lv: 0.865 pu
# Voltage warning at p1rdt3459: 0.877 pu
# Voltage warning at p1rdt3459lv: 0.859 pu
# Voltage warning at p1rdt3459lv: 0.860 pu
# Voltage warning at p1rdt3460: 0.877 pu
# Voltage warning at p1rdt3460lv: 0.865 pu
# Voltage warning at p1rdt3460lv: 0.866 pu
# Voltage warning at p1rdt3461: 0.868 pu
# Voltage warning at p1rdt3461lv: 0.854 pu
# Voltage warning at p1rdt3461lv: 0.854 pu
# Voltage warning at p1rdt3462: 0.869 pu
# Voltage warning at p1rdt3462lv: 0.858 pu
# Voltage warning at p1rdt3462lv: 0.859 pu
# Voltage warning at p1rdt3463: 0.869 pu
# Voltage warning at p1rdt3463lv: 0.860 pu
# Voltage warning at p1rdt3463lv: 0.860 pu
# Voltage warning at p1rdt3464: 0.869 pu
# Voltage warning at p1rdt3464lv: 0.857 pu
# Voltage warning at p1rdt3464lv: 0.858 pu
# Voltage warning at p1rdt3465: 0.877 pu
# Voltage warning at p1rdt3465lv: 0.864 pu
# Voltage warning at p1rdt3465lv: 0.865 pu
# Voltage warning at p1rdt3466: 0.877 pu
# Voltage warning at p1rdt3466lv: 0.861 pu
# Voltage warning at p1rdt3466lv: 0.861 pu
# Voltage warning at p1rdt3467: 0.877 pu
# Voltage warning at p1rdt3467lv: 0.861 pu
# Voltage warning at p1rdt3467lv: 0.862 pu
# Voltage warning at p1rdt3468: 0.869 pu
# Voltage warning at p1rdt3468lv: 0.857 pu
# Voltage warning at p1rdt3468lv: 0.858 pu
# Voltage warning at p1rdt3469: 0.877 pu
# Voltage warning at p1rdt3469: 0.867 pu
# Voltage warning at p1rdt3469: 0.869 pu
# Voltage warning at p1rdt3469lv: 0.866 pu
# Voltage warning at p1rdt3469lv: 0.856 pu
# Voltage warning at p1rdt3469lv: 0.858 pu
# Voltage warning at p1rdt3470: 0.877 pu
# Voltage warning at p1rdt3470: 0.867 pu
# Voltage warning at p1rdt3470: 0.869 pu
# Voltage warning at p1rdt3470lv: 0.858 pu
# Voltage warning at p1rdt3470lv: 0.858 pu
# Voltage warning at p1rdt3471: 0.867 pu
# Voltage warning at p1rdt3471lv: 0.862 pu
# Voltage warning at p1rdt3471lv: 0.863 pu
# Voltage warning at p1rdt3472: 0.881 pu
# Voltage warning at p1rdt3472lv: 0.876 pu
# Voltage warning at p1rdt3472lv: 0.876 pu
# Voltage warning at p1rdt3473: 0.881 pu
# Voltage warning at p1rdt3473lv: 0.874 pu
# Voltage warning at p1rdt3473lv: 0.874 pu
# Voltage warning at p1rdt3474: 0.874 pu
# Voltage warning at p1rdt3474lv: 0.868 pu
# Voltage warning at p1rdt3474lv: 0.869 pu
# Voltage warning at p1rdt3475: 0.873 pu
# Voltage warning at p1rdt3475lv: 0.862 pu
# Voltage warning at p1rdt3475lv: 0.863 pu
# Voltage warning at p1rdt3476: 0.873 pu
# Voltage warning at p1rdt3476lv: 0.864 pu
# Voltage warning at p1rdt3476lv: 0.865 pu
# Voltage warning at p1rdt3477: 0.881 pu
# Voltage warning at p1rdt3477: 0.871 pu
# Voltage warning at p1rdt3477: 0.873 pu
# Voltage warning at p1rdt3477lv: 0.865 pu
# Voltage warning at p1rdt3477lv: 0.865 pu
# Voltage warning at p1rdt3478: 0.882 pu
# Voltage warning at p1rdt3478: 0.871 pu
# Voltage warning at p1rdt3478: 0.873 pu
# Voltage warning at p1rdt3478lv: 0.861 pu
# Voltage warning at p1rdt3478lv: 0.862 pu
# Voltage warning at p1rdt3479: 0.882 pu
# Voltage warning at p1rdt3479: 0.871 pu
# Voltage warning at p1rdt3479: 0.873 pu
# Voltage warning at p1rdt3479lv: 0.870 pu
# Voltage warning at p1rdt3479lv: 0.871 pu
# Voltage warning at p1rdt3480: 0.874 pu
# Voltage warning at p1rdt3480lv: 0.862 pu
# Voltage warning at p1rdt3480lv: 0.863 pu
# Voltage warning at p1rdt3481: 0.883 pu
# Voltage warning at p1rdt3481: 0.872 pu
# Voltage warning at p1rdt3481: 0.874 pu
# Voltage warning at p1rdt3481lv: 0.857 pu
# Voltage warning at p1rdt3481lv: 0.859 pu
# Voltage warning at p1rdt3482: 0.874 pu
# Voltage warning at p1rdt3482lv: 0.868 pu
# Voltage warning at p1rdt3482lv: 0.868 pu
# Voltage warning at p1rdt3483: 0.880 pu
# Voltage warning at p1rdt3483: 0.870 pu
# Voltage warning at p1rdt3483: 0.872 pu
# Voltage warning at p1rdt3483lv: 0.867 pu
# Voltage warning at p1rdt3483lv: 0.867 pu
# Voltage warning at p1rdt3484: 0.884 pu
# Voltage warning at p1rdt3484: 0.873 pu
# Voltage warning at p1rdt3484: 0.875 pu
# Voltage warning at p1rdt3484lv: 0.867 pu
# Voltage warning at p1rdt3484lv: 0.867 pu
# Voltage warning at p1rdt3485: 0.883 pu
# Voltage warning at p1rdt3485: 0.873 pu
# Voltage warning at p1rdt3485: 0.875 pu
# Voltage warning at p1rdt3485lv: 0.858 pu
# Voltage warning at p1rdt3485lv: 0.859 pu
# Voltage warning at p1rdt3486: 0.883 pu
# Voltage warning at p1rdt3486: 0.873 pu
# Voltage warning at p1rdt3486: 0.875 pu
# Voltage warning at p1rdt3486lv: 0.860 pu
# Voltage warning at p1rdt3486lv: 0.861 pu
# Voltage warning at p1rdt3487: 0.875 pu
# Voltage warning at p1rdt3487lv: 0.862 pu
# Voltage warning at p1rdt3487lv: 0.862 pu
# Voltage warning at p1rdt3488: 0.873 pu
# Voltage warning at p1rdt3488lv: 0.865 pu
# Voltage warning at p1rdt3488lv: 0.865 pu
# Voltage warning at p1rdt3489: 0.874 pu
# Voltage warning at p1rdt3489lv: 0.864 pu
# Voltage warning at p1rdt3489lv: 0.865 pu
# Voltage warning at p1rdt3490: 0.874 pu
# Voltage warning at p1rdt3490lv: 0.865 pu
# Voltage warning at p1rdt3490lv: 0.865 pu
# Voltage warning at p1rdt3491: 0.890 pu
# Voltage warning at p1rdt3491: 0.880 pu
# Voltage warning at p1rdt3491: 0.881 pu
# Voltage warning at p1rdt3491lv: 0.878 pu
# Voltage warning at p1rdt3491lv: 0.878 pu
# Voltage warning at p1rdt3492: 0.874 pu
# Voltage warning at p1rdt3492lv: 0.870 pu
# Voltage warning at p1rdt3492lv: 0.870 pu
# Voltage warning at p1rdt3493: 0.890 pu
# Voltage warning at p1rdt3493: 0.880 pu
# Voltage warning at p1rdt3493: 0.882 pu
# Voltage warning at p1rdt3493lv: 0.877 pu
# Voltage warning at p1rdt3493lv: 0.877 pu
# Voltage warning at p1rdt3494: 0.889 pu
# Voltage warning at p1rdt3494: 0.879 pu
# Voltage warning at p1rdt3494: 0.881 pu
# Voltage warning at p1rdt3494lv: 0.885 pu
# Voltage warning at p1rdt3494lv: 0.886 pu
# Voltage warning at p1rdt3495: 0.889 pu
# Voltage warning at p1rdt3495: 0.879 pu
# Voltage warning at p1rdt3495: 0.881 pu
# Voltage warning at p1rdt3495lv: 0.879 pu
# Voltage warning at p1rdt3495lv: 0.869 pu
# Voltage warning at p1rdt3495lv: 0.870 pu
# Voltage warning at p1rdt3555: 0.867 pu
# Voltage warning at p1rdt3555: 0.856 pu
# Voltage warning at p1rdt3555: 0.861 pu
# Voltage warning at p1rdt3555lv: 0.854 pu
# Voltage warning at p1rdt3555lv: 0.855 pu
# Voltage warning at p1rdt3558: 0.867 pu
# Voltage warning at p1rdt3558lv: 0.860 pu
# Voltage warning at p1rdt3558lv: 0.860 pu
# Voltage warning at p1rdt3560: 0.855 pu
# Voltage warning at p1rdt3560lv: 0.847 pu
# Voltage warning at p1rdt3560lv: 0.847 pu
# Voltage warning at p1rdt3580: 0.884 pu
# Voltage warning at p1rdt3580: 0.874 pu
# Voltage warning at p1rdt3580: 0.875 pu
# Voltage warning at p1rdt3580lv: 0.870 pu
# Voltage warning at p1rdt3580lv: 0.870 pu
# Voltage warning at p1rdt3581: 0.873 pu
# Voltage warning at p1rdt3581lv: 0.865 pu
# Voltage warning at p1rdt3581lv: 0.865 pu
# Voltage warning at p1rdt3582: 0.882 pu
# Voltage warning at p1rdt3582: 0.872 pu
# Voltage warning at p1rdt3582: 0.874 pu
# Voltage warning at p1rdt3582lv: 0.863 pu
# Voltage warning at p1rdt3582lv: 0.864 pu
# Voltage warning at p1rdt3583: 0.882 pu
# Voltage warning at p1rdt3583: 0.872 pu
# Voltage warning at p1rdt3583: 0.874 pu
# Voltage warning at p1rdt3583lv: 0.865 pu
# Voltage warning at p1rdt3583lv: 0.866 pu
# Voltage warning at p1rdt3584: 0.872 pu
# Voltage warning at p1rdt3584lv: 0.867 pu
# Voltage warning at p1rdt3584lv: 0.867 pu
# Voltage warning at p1rdt3585: 0.882 pu
# Voltage warning at p1rdt3585: 0.872 pu
# Voltage warning at p1rdt3585: 0.874 pu
# Voltage warning at p1rdt3585lv: 0.877 pu
# Voltage warning at p1rdt3585lv: 0.877 pu
# Voltage warning at p1rdt3586: 0.874 pu
# Voltage warning at p1rdt3586lv: 0.861 pu
# Voltage warning at p1rdt3586lv: 0.862 pu
# Voltage warning at p1rdt3587: 0.874 pu
# Voltage warning at p1rdt3587lv: 0.867 pu
# Voltage warning at p1rdt3587lv: 0.867 pu
# Voltage warning at p1rdt3588: 0.873 pu
# Voltage warning at p1rdt3588lv: 0.868 pu
# Voltage warning at p1rdt3588lv: 0.868 pu
# Voltage warning at p1rdt3589: 0.873 pu
# Voltage warning at p1rdt3589lv: 0.868 pu
# Voltage warning at p1rdt3589lv: 0.868 pu
# Voltage warning at p1rdt3590: 0.882 pu
# Voltage warning at p1rdt3590: 0.872 pu
# Voltage warning at p1rdt3590: 0.874 pu
# Voltage warning at p1rdt3590lv: 0.861 pu
# Voltage warning at p1rdt3590lv: 0.861 pu
# Voltage warning at p1rdt3591: 0.882 pu
# Voltage warning at p1rdt3591: 0.872 pu
# Voltage warning at p1rdt3591: 0.874 pu
# Voltage warning at p1rdt3591lv: 0.862 pu
# Voltage warning at p1rdt3591lv: 0.863 pu
# Voltage warning at p1rdt3592: 0.871 pu
# Voltage warning at p1rdt3592lv: 0.861 pu
# Voltage warning at p1rdt3592lv: 0.861 pu
# Voltage warning at p1rdt3778: 0.867 pu
# Voltage warning at p1rdt3778: 0.856 pu
# Voltage warning at p1rdt3778: 0.861 pu
# Voltage warning at p1rdt3778lv: 0.846 pu
# Voltage warning at p1rdt3778lv: 0.848 pu
# Voltage warning at p1rdt3779: 0.867 pu
# Voltage warning at p1rdt3779: 0.856 pu
# Voltage warning at p1rdt3779: 0.861 pu
# Voltage warning at p1rdt3779lv: 0.835 pu
# Voltage warning at p1rdt3779lv: 0.836 pu
# Voltage warning at p1rdt3780: 0.867 pu
# Voltage warning at p1rdt3780: 0.856 pu
# Voltage warning at p1rdt3780: 0.861 pu
# Voltage warning at p1rdt3780lv: 0.858 pu
# Voltage warning at p1rdt3780lv: 0.858 pu
# Voltage warning at p1rdt3781: 0.867 pu
# Voltage warning at p1rdt3781: 0.856 pu
# Voltage warning at p1rdt3781: 0.861 pu
# Voltage warning at p1rdt3781lv: 0.855 pu
# Voltage warning at p1rdt3781lv: 0.843 pu
# Voltage warning at p1rdt3781lv: 0.849 pu
# Voltage warning at p1rdt3782: 0.861 pu
# Voltage warning at p1rdt3782lv: 0.855 pu
# Voltage warning at p1rdt3782lv: 0.855 pu
# Voltage warning at p1rdt4478: 0.867 pu
# Voltage warning at p1rdt4478: 0.856 pu
# Voltage warning at p1rdt4478: 0.861 pu
# Voltage warning at p1rdt4478lv: 0.856 pu
# Voltage warning at p1rdt4478lv: 0.845 pu
# Voltage warning at p1rdt4478lv: 0.851 pu
# Voltage warning at p1rdt4479: 0.861 pu
# Voltage warning at p1rdt4479lv: 0.856 pu
# Voltage warning at p1rdt4479lv: 0.857 pu
# Voltage warning at p1rdt4480: 0.867 pu
# Voltage warning at p1rdt4480: 0.856 pu
# Voltage warning at p1rdt4480: 0.861 pu
# Voltage warning at p1rdt4480lv: 0.848 pu
# Voltage warning at p1rdt4480lv: 0.849 pu
# Voltage warning at p1rdt4481: 0.867 pu
# Voltage warning at p1rdt4481: 0.856 pu
# Voltage warning at p1rdt4481: 0.861 pu
# Voltage warning at p1rdt4481lv: 0.852 pu
# Voltage warning at p1rdt4481lv: 0.852 pu
# Voltage warning at p1rdt4482: 0.867 pu
# Voltage warning at p1rdt4482lv: 0.858 pu
# Voltage warning at p1rdt4482lv: 0.858 pu
# Voltage warning at p1rdt4483: 0.878 pu
# Voltage warning at p1rdt4483lv: 0.873 pu
# Voltage warning at p1rdt4483lv: 0.874 pu
# Voltage warning at p1rdt4484: 0.878 pu
# Voltage warning at p1rdt4484lv: 0.868 pu
# Voltage warning at p1rdt4484lv: 0.869 pu
# Voltage warning at p1rdt4485: 0.878 pu
# Voltage warning at p1rdt4485lv: 0.868 pu
# Voltage warning at p1rdt4485lv: 0.869 pu
# Voltage warning at p1rdt4486: 0.878 pu
# Voltage warning at p1rdt4486lv: 0.869 pu
# Voltage warning at p1rdt4486lv: 0.870 pu
# Voltage warning at p1rdt4487: 0.878 pu
# Voltage warning at p1rdt4487lv: 0.868 pu
# Voltage warning at p1rdt4487lv: 0.868 pu
# Voltage warning at p1rdt4488: 0.879 pu
# Voltage warning at p1rdt4488: 0.870 pu
# Voltage warning at p1rdt4488: 0.871 pu
# Voltage warning at p1rdt4488lv: 0.851 pu
# Voltage warning at p1rdt4488lv: 0.852 pu
# Voltage warning at p1rdt4489: 0.880 pu
# Voltage warning at p1rdt4489: 0.870 pu
# Voltage warning at p1rdt4489: 0.871 pu
# Voltage warning at p1rdt4489lv: 0.861 pu
# Voltage warning at p1rdt4489lv: 0.861 pu
# Voltage warning at p1rdt4490: 0.878 pu
# Voltage warning at p1rdt4490lv: 0.871 pu
# Voltage warning at p1rdt4490lv: 0.871 pu
# Voltage warning at p1rdt4491: 0.878 pu
# Voltage warning at p1rdt4491lv: 0.871 pu
# Voltage warning at p1rdt4491lv: 0.872 pu
# Voltage warning at p1rdt4492: 0.880 pu
# Voltage warning at p1rdt4492: 0.870 pu
# Voltage warning at p1rdt4492: 0.871 pu
# Voltage warning at p1rdt4492lv: 0.859 pu
# Voltage warning at p1rdt4492lv: 0.860 pu
# Voltage warning at p1rdt4493: 0.878 pu
# Voltage warning at p1rdt4493lv: 0.867 pu
# Voltage warning at p1rdt4493lv: 0.868 pu
# Voltage warning at p1rdt4494: 0.870 pu
# Voltage warning at p1rdt4494lv: 0.861 pu
# Voltage warning at p1rdt4494lv: 0.862 pu
# Voltage warning at p1rdt4495: 0.878 pu
# Voltage warning at p1rdt4495lv: 0.872 pu
# Voltage warning at p1rdt4495lv: 0.872 pu
# Voltage warning at p1rdt4496: 0.878 pu
# Voltage warning at p1rdt4496lv: 0.872 pu
# Voltage warning at p1rdt4496lv: 0.873 pu
# Voltage warning at p1rdt4497: 0.870 pu
# Voltage warning at p1rdt4497lv: 0.866 pu
# Voltage warning at p1rdt4497lv: 0.866 pu
# Voltage warning at p1rdt4498: 0.881 pu
# Voltage warning at p1rdt4498lv: 0.879 pu
# Voltage warning at p1rdt4498lv: 0.879 pu
# Voltage warning at p1rdt4521: 0.861 pu
# Voltage warning at p1rdt4521lv: 0.843 pu
# Voltage warning at p1rdt4521lv: 0.845 pu
# Voltage warning at p1rdt4522: 0.861 pu
# Voltage warning at p1rdt4522lv: 0.853 pu
# Voltage warning at p1rdt4522lv: 0.853 pu
# Voltage warning at p1rdt4523: 0.861 pu
# Voltage warning at p1rdt4523lv: 0.856 pu
# Voltage warning at p1rdt4523lv: 0.857 pu
# Voltage warning at p1rdt4524: 0.867 pu
# Voltage warning at p1rdt4524: 0.856 pu
# Voltage warning at p1rdt4524: 0.862 pu
# Voltage warning at p1rdt4524lv: 0.856 pu
# Voltage warning at p1rdt4524lv: 0.857 pu
# Voltage warning at p1rdt4525: 0.867 pu
# Voltage warning at p1rdt4525: 0.856 pu
# Voltage warning at p1rdt4525: 0.862 pu
# Voltage warning at p1rdt4525lv: 0.859 pu
# Voltage warning at p1rdt4525lv: 0.848 pu
# Voltage warning at p1rdt4525lv: 0.854 pu
# Voltage warning at p1rdt4526: 0.855 pu
# Voltage warning at p1rdt4526lv: 0.848 pu
# Voltage warning at p1rdt4526lv: 0.849 pu
# Voltage warning at p1rdt4527: 0.867 pu
# Voltage warning at p1rdt4527: 0.856 pu
# Voltage warning at p1rdt4527: 0.861 pu
# Voltage warning at p1rdt4527lv: 0.862 pu
# Voltage warning at p1rdt4527lv: 0.862 pu
# Voltage warning at p1rdt4531: 0.855 pu
# Voltage warning at p1rdt4531lv: 0.845 pu
# Voltage warning at p1rdt4531lv: 0.846 pu
# Voltage warning at p1rdt4532: 0.867 pu
# Voltage warning at p1rdt4532: 0.856 pu
# Voltage warning at p1rdt4532: 0.861 pu
# Voltage warning at p1rdt4532lv: 0.857 pu
# Voltage warning at p1rdt4532lv: 0.846 pu
# Voltage warning at p1rdt4532lv: 0.851 pu
# Voltage warning at p1rdt4533: 0.861 pu
# Voltage warning at p1rdt4533lv: 0.854 pu
# Voltage warning at p1rdt4533lv: 0.855 pu
# Voltage warning at p1rdt4534: 0.867 pu
# Voltage warning at p1rdt4534: 0.856 pu
# Voltage warning at p1rdt4534: 0.861 pu
# Voltage warning at p1rdt4534lv: 0.855 pu
# Voltage warning at p1rdt4534lv: 0.843 pu
# Voltage warning at p1rdt4534lv: 0.849 pu
# Voltage warning at p1rdt4657: 0.879 pu
# Voltage warning at p1rdt4657: 0.869 pu
# Voltage warning at p1rdt4657: 0.871 pu
# Voltage warning at p1rdt4657lv: 0.871 pu
# Voltage warning at p1rdt4657lv: 0.861 pu
# Voltage warning at p1rdt4657lv: 0.863 pu
# Voltage warning at p1rdt4658: 0.872 pu
# Voltage warning at p1rdt4658: 0.861 pu
# Voltage warning at p1rdt4658: 0.865 pu
# Voltage warning at p1rdt4658lv: 0.868 pu
# Voltage warning at p1rdt4658lv: 0.868 pu
# Voltage warning at p1rdt4660: 0.866 pu
# Voltage warning at p1rdt4660: 0.855 pu
# Voltage warning at p1rdt4660: 0.861 pu
# Voltage warning at p1rdt4660lv: 0.844 pu
# Voltage warning at p1rdt4660lv: 0.832 pu
# Voltage warning at p1rdt4660lv: 0.838 pu
# Voltage warning at p1rdt1577-p1rdt3816xx: 0.883 pu
# Voltage warning at p1rdt1577-p1rdt3816xx: 0.876 pu
# Voltage warning at p1rdt1577-p1rdt3816xx: 0.876 pu
# Voltage warning at p1rdt1642lv: 0.899 pu
# Voltage warning at p1rdt1642lv: 0.899 pu
# Voltage warning at p1rdt1643lv: 0.895 pu
# Voltage warning at p1rdt1643lv: 0.896 pu
# Voltage warning at p1rdt1645lv: 0.897 pu
# Voltage warning at p1rdt1645lv: 0.897 pu
# Voltage warning at p1rdt1646lv: 0.899 pu
# Voltage warning at p1rdt1646lv: 0.900 pu
# Voltage warning at p1rdt1654lv: 0.899 pu
# Voltage warning at p1rdt1654lv: 0.900 pu
# Voltage warning at p1rdt2098lv: 0.899 pu
# Voltage warning at p1rdt2098lv: 0.900 pu
# Voltage warning at p1rdt2955lv: 0.899 pu
# Voltage warning at p1rdt2955lv: 0.900 pu
# Voltage warning at p1rdt3906lv: 0.897 pu
# Voltage warning at p1rdt3906lv: 0.898 pu
# Voltage warning at p1rdt3911lv: 0.898 pu
# Voltage warning at p1rdt3911lv: 0.898 pu
# Voltage warning at p1rdt4590lv: 0.894 pu
# Voltage warning at p1rdt4590lv: 0.894 pu
# Voltage warning at p1rdt4598lv: 0.895 pu
# Voltage warning at p1rdt4598lv: 0.896 pu
# Voltage warning at p1rdt1386lv: 0.898 pu
# Voltage warning at p1rdt1386lv: 0.898 pu
# Voltage warning at p1rdt1505lv: 0.888 pu
# Voltage warning at p1rdt1505lv: 0.889 pu
# Voltage warning at p1rdt1508lv: 0.897 pu
# Voltage warning at p1rdt1508lv: 0.897 pu
# Voltage warning at p1rdt2543lv: 0.900 pu
# Voltage warning at p1rdt2543lv: 0.900 pu
# Voltage warning at p1rdt3379lv: 0.894 pu
# Voltage warning at p1rdt3379lv: 0.894 pu
# Voltage warning at p1rdt3380lv: 0.893 pu
# Voltage warning at p1rdt3380lv: 0.894 pu
# Voltage warning at p1rdt3381lv: 0.895 pu
# Voltage warning at p1rdt3381lv: 0.896 pu
# Voltage warning at p1rdt3383lv: 0.894 pu
# Voltage warning at p1rdt3383lv: 0.895 pu
# Voltage warning at p1rdt1693lv: 0.895 pu
# Voltage warning at p1rdt1693lv: 0.896 pu
# Voltage warning at p1rdt2055lv: 0.897 pu
# Voltage warning at p1rdt2055lv: 0.898 pu
# Voltage warning at p1rdt3559lv: 0.899 pu
# Voltage warning at p1rdt3559lv: 0.900 pu
# Voltage warning at p1rdt3561lv: 0.899 pu
# Voltage warning at p1rdt3565lv: 0.899 pu
# Voltage warning at p1rdt3565lv: 0.900 pu
# Voltage warning at p1rdt3688lv: 0.899 pu
# Voltage warning at p1rdt3688lv: 0.900 pu
# Voltage warning at p1rdt3693lv: 0.899 pu
# Voltage warning at p1rdt3706lv: 0.899 pu
# Voltage warning at p1rdt3706lv: 0.899 pu
# Voltage warning at p1rdt3708lv: 0.898 pu
# Voltage warning at p1rdt3708lv: 0.898 pu
# Voltage warning at p1rdt3710lv: 0.900 pu
# Voltage warning at p1rdt3714lv: 0.892 pu
# Voltage warning at p1rdt3714lv: 0.893 pu
# Voltage warning at p1rdt3716lv: 0.898 pu
# Voltage warning at p1rdt3716lv: 0.898 pu
# Voltage warning at p1rdt4269lv: 0.894 pu
# Voltage warning at p1rdt4269lv: 0.895 pu
# Voltage warning at p1rdt4505lv: 0.900 pu
# Voltage warning at p1rdt4508lv: 0.899 pu
# Voltage warning at p1rdt4508lv: 0.900 pu
# Voltage warning at p1rdt4509lv: 0.898 pu
# Voltage warning at p1rdt4509lv: 0.898 pu
# Voltage warning at p1rdt4515lv: 0.896 pu
# Voltage warning at p1rdt4515lv: 0.897 pu
# Voltage warning at p1rdt4819: 0.886 pu
# Voltage warning at p1rdt4819lv: 0.876 pu
# Voltage warning at p1rdt4819lv: 0.876 pu
# Voltage warning at p1rdt4869lv: 0.887 pu
# Voltage warning at p1rdt4869lv: 0.887 pu
# Voltage warning at p1rdt4871lv: 0.891 pu
# Voltage warning at p1rdt4871lv: 0.891 pu
# Voltage warning at p1rdt4879: 0.886 pu
# Voltage warning at p1rdt4879lv: 0.883 pu
# Voltage warning at p1rdt4879lv: 0.883 pu
# Voltage warning at p1rdt4885: 0.886 pu
# Voltage warning at p1rdt4885lv: 0.873 pu
# Voltage warning at p1rdt4885lv: 0.874 pu
# Voltage warning at p1rdt4889: 0.884 pu
# Voltage warning at p1rdt4889lv: 0.892 pu
# Voltage warning at p1rdt4889lv: 0.892 pu
# Voltage warning at p1rdt4895: 0.884 pu
# Voltage warning at p1rdt4895lv: 0.894 pu
# Voltage warning at p1rdt4895lv: 0.894 pu
# Voltage warning at p1rdt4897: 0.885 pu
# Voltage warning at p1rdt4897lv: 0.879 pu
# Voltage warning at p1rdt4897lv: 0.879 pu
# Voltage warning at p1rdt4910: 0.884 pu
# Voltage warning at p1rdt4910lv: 0.876 pu
# Voltage warning at p1rdt4910lv: 0.876 pu
# Voltage warning at p1rdt5585lv: 0.897 pu
# Voltage warning at p1rdt5585lv: 0.898 pu
# Voltage warning at p1rdt5586lv: 0.894 pu
# Voltage warning at p1rdt5586lv: 0.895 pu
# Voltage warning at p1rdt5590lv: 0.895 pu
# Voltage warning at p1rdt5590lv: 0.896 pu
# Voltage warning at p1rdt5594lv: 0.897 pu
# Voltage warning at p1rdt5594lv: 0.898 pu
# Voltage warning at p1rdt5597lv: 0.897 pu
# Voltage warning at p1rdt5597lv: 0.898 pu
# Voltage warning at p1rdt5603lv: 0.897 pu
# Voltage warning at p1rdt5603lv: 0.897 pu
# Voltage warning at p1rdt5608lv: 0.889 pu
# Voltage warning at p1rdt5608lv: 0.890 pu
# Voltage warning at p1rdt5613lv: 0.900 pu
# Voltage warning at p1rdt5613lv: 0.900 pu
# Voltage warning at p1rdt5627lv: 0.891 pu
# Voltage warning at p1rdt5627lv: 0.892 pu
# Voltage warning at p1rdt5628lv: 0.895 pu
# Voltage warning at p1rdt5628lv: 0.895 pu
# Voltage warning at p1rdt5630lv: 0.896 pu
# Voltage warning at p1rdt5630lv: 0.897 pu
# Voltage warning at p1rdt5634lv: 0.900 pu
# Voltage warning at p1rdt6238: 0.887 pu
# Voltage warning at p1rdt6238lv: 0.891 pu
# Voltage warning at p1rdt6238lv: 0.892 pu
# Voltage warning at p1rdt6246: 0.890 pu
# Voltage warning at p1rdt6246lv: 0.884 pu
# Voltage warning at p1rdt6246lv: 0.885 pu
# Voltage warning at p1rdt6247: 0.886 pu
# Voltage warning at p1rdt6247lv: 0.894 pu
# Voltage warning at p1rdt6247lv: 0.894 pu
# Voltage warning at p1rdt6252: 0.885 pu
# Voltage warning at p1rdt6252lv: 0.880 pu
# Voltage warning at p1rdt6252lv: 0.880 pu
# Voltage warning at p1rdt7105: 0.890 pu
# Voltage warning at p1rdt7105lv: 0.897 pu
# Voltage warning at p1rdt7105lv: 0.898 pu
# Voltage warning at p1rdt7108: 0.891 pu
# Voltage warning at p1rdt7108lv: 0.895 pu
# ...
# Voltage warning at p1rdt18141-p1rdt18145x: 0.807 pu
# Voltage warning at p1rdt17701-p1rdt17702x: 0.797 pu
# Voltage warning at p1rdt17701-p1rdt17702xx: 0.797 pu
# Voltage warning at p1rdt17701-p1rdt17732xx: 0.797 pu
# Voltage warning at p1rdt17701-p1rdt17732x: 0.797 pu
# Voltage warning at p1rdt17650-p1rdt17732x: 0.797 pu
# Voltage warning at p1rdt17650-p1rdt17732xx: 0.797 pu
# Voltage warning at p1rdt17650-p1rdt18165xx: 0.798 pu
# Voltage warning at p1rdt17650-p1rdt18165x: 0.797 pu
# Voltage warning at p1rdt18133-p1rdt18153x: 0.791 pu
# Voltage warning at p1rdt18133-p1rdt18153xx: 0.791 pu
# Voltage warning at p1rdt18133-p1rdt18165xx: 0.791 pu
# Voltage warning at p1rdt18133-p1rdt18165x: 0.791 pu
# Voltage warning at p1rdt18155-p1rdt18162x: 0.798 pu
# Voltage warning at p1rdt17504-p1rdt17506x: 0.808 pu
# Voltage warning at p1rdt17525-p1rdt17570xx: 0.827 pu
# Voltage warning at p1rdt17525-p1rdt17570x: 0.827 pu
# Voltage warning at p1rdt18100-p1rdt18104x: 0.821 pu
# Voltage warning at p1rdt18104-p1rdt18108x: 0.813 pu
# Voltage warning at p1rdt17315-p1rdt17325x: 0.859 pu
# Voltage warning at p1rdt18061-p1rdt18071x: 0.858 pu
# Voltage warning at p1rdt17435-p1rdt17444x: 0.846 pu
# Voltage warning at p1rdt17436-p1rdt17449x: 0.843 pu
# Voltage warning at p1rdt17295-p1rdt17320x: 0.833 pu
# Voltage warning at p1rdt17434-p1rdt17977x: 0.834 pu
# Voltage warning at p1rdt17978-p1rdt17984x: 0.843 pu
# Voltage warning at p1rdt17976-p1rdt17986x: 0.844 pu
# Voltage warning at p1rdt17976-p1rdt17985xx: 0.844 pu
# Voltage warning at p1rdt17976-p1rdt17985x: 0.844 pu
# Voltage warning at p1rdt17979-p1rdt17984x: 0.845 pu
# Voltage warning at p1rdt17984-p1rdt17991x: 0.834 pu
# Voltage warning at p1rdt17447-p1rdt17450x: 0.843 pu
# Voltage warning at p1rdt17449-p1rdt17454x: 0.846 pu
# Voltage warning at p1rdt17591-p1rdt17592x: 0.829 pu
# Voltage warning at p1rdt16561-p1rdt17592x: 0.830 pu
# Voltage warning at p1rdt16557-p1rdt16594x: 0.831 pu
# Voltage warning at p1rdt16574-p1rdt16594x: 0.831 pu
# Voltage warning at p1rdt16565-p1rdt16594x: 0.832 pu
# Voltage warning at p1rdt16498-p1rdt16673x: 0.847 pu
# Voltage warning at p1rdt16370-p1rdt16672xx: 0.847 pu
# Voltage warning at p1rdt16370-p1rdt16672x: 0.847 pu
# Voltage warning at p1rdt17397-p1rdt17398x: 0.840 pu
# Voltage warning at p1rdt17397-p1rdt17398xx: 0.840 pu
# Voltage warning at p1rdt17384-p1rdt17397x: 0.840 pu
# Voltage warning at p1rdt17600-p1rdt17602x: 0.847 pu
# Voltage warning at p1rdt17600-p1rdt17602xx: 0.847 pu
# Voltage warning at p1rdt16668-p1rdt17598x: 0.847 pu
# Voltage warning at p1rdt16363-p1rdt16998x: 0.897 pu
# Voltage warning at p1rdt18085-p1rdt18087x: 0.832 pu
# Voltage warning at p1rdt18085-p1rdt18087x: 0.823 pu
# Voltage warning at p1rdt18085-p1rdt18087x: 0.841 pu
# Voltage warning at p1rdt18085-p1rdt18087xx: 0.832 pu
# Voltage warning at p1rdt18085-p1rdt18087xx: 0.823 pu
# Voltage warning at p1rdt18085-p1rdt18087xx: 0.841 pu
# Voltage warning at p1rdt18085-p1rdt18087xxx: 0.832 pu
# Voltage warning at p1rdt18085-p1rdt18087xxx: 0.823 pu
# Voltage warning at p1rdt18085-p1rdt18087xxx: 0.841 pu
# Voltage warning at p1rdt17160-p1rdt17161x: 0.832 pu
# Voltage warning at p1rdt17160-p1rdt17161x: 0.823 pu
# Voltage warning at p1rdt17160-p1rdt17161x: 0.841 pu
# Voltage warning at p1rdt17158-p1rdt17164x: 0.833 pu
# Voltage warning at p1rdt17158-p1rdt17164x: 0.825 pu
# Voltage warning at p1rdt17158-p1rdt17164x: 0.842 pu
# Voltage warning at p1rdt17533-p1rdt17542x: 0.810 pu
# Voltage warning at p1rdt17533-p1rdt17542x: 0.803 pu
# Voltage warning at p1rdt17533-p1rdt17542x: 0.820 pu
# Voltage warning at p1rdt17642-p1rdt17681xxx: 0.800 pu
# Voltage warning at p1rdt17642-p1rdt17681xxx: 0.794 pu
# Voltage warning at p1rdt17642-p1rdt17681xxx: 0.811 pu
# Voltage warning at p1rdt17642-p1rdt17681xx: 0.800 pu
# Voltage warning at p1rdt17642-p1rdt17681xx: 0.794 pu
# Voltage warning at p1rdt17642-p1rdt17681xx: 0.811 pu
# Voltage warning at p1rdt17642-p1rdt17681x: 0.800 pu
# Voltage warning at p1rdt17642-p1rdt17681x: 0.794 pu
# Voltage warning at p1rdt17642-p1rdt17681x: 0.811 pu
# Voltage warning at p1rdt17644-p1rdt17657x: 0.800 pu
# Voltage warning at p1rdt17644-p1rdt17657x: 0.794 pu
# Voltage warning at p1rdt17644-p1rdt17657x: 0.811 pu
# Voltage warning at p1rdt17644-p1rdt17657xx: 0.800 pu
# Voltage warning at p1rdt17644-p1rdt17657xx: 0.794 pu
# Voltage warning at p1rdt17644-p1rdt17657xx: 0.811 pu
# Voltage warning at p1rdt17644-p1rdt17657xxx: 0.800 pu
# Voltage warning at p1rdt17644-p1rdt17657xxx: 0.794 pu
# Voltage warning at p1rdt17644-p1rdt17657xxx: 0.811 pu
# Voltage warning at p1rdt18110-p1rdt18136x: 0.800 pu
# Voltage warning at p1rdt18110-p1rdt18136x: 0.794 pu
# Voltage warning at p1rdt18110-p1rdt18136x: 0.811 pu
# Voltage warning at p1rdt17441-p1rdt18161x: 0.803 pu
# Voltage warning at p1rdt17441-p1rdt18161x: 0.796 pu
# Voltage warning at p1rdt17441-p1rdt18161x: 0.813 pu
# Voltage warning at p1rdt17433-p1rdt17441x: 0.804 pu
# Voltage warning at p1rdt17433-p1rdt17441x: 0.797 pu
# Voltage warning at p1rdt17433-p1rdt17441x: 0.814 pu
# Voltage warning at p1rdt17723-p1rdt17731xx: 0.798 pu
# Voltage warning at p1rdt17723-p1rdt17731xx: 0.791 pu
# Voltage warning at p1rdt17723-p1rdt17731xx: 0.806 pu
# Voltage warning at p1rdt17723-p1rdt17731x: 0.798 pu
# Voltage warning at p1rdt17723-p1rdt17731x: 0.790 pu
# Voltage warning at p1rdt17723-p1rdt17731x: 0.806 pu
# Voltage warning at p1rdt17731-p1rdt18132xx: 0.798 pu
# Voltage warning at p1rdt17731-p1rdt18132xx: 0.791 pu
# Voltage warning at p1rdt17731-p1rdt18132xx: 0.807 pu
# Voltage warning at p1rdt17731-p1rdt18132x: 0.798 pu
# Voltage warning at p1rdt17731-p1rdt18132x: 0.791 pu
# Voltage warning at p1rdt17731-p1rdt18132x: 0.806 pu
# Voltage warning at p1rdt18145-p1rdt18165x: 0.798 pu
# Voltage warning at p1rdt18145-p1rdt18165x: 0.791 pu
# Voltage warning at p1rdt18145-p1rdt18165x: 0.807 pu
# Voltage warning at p1rdt18145-p1rdt18165xx: 0.798 pu
# Voltage warning at p1rdt18145-p1rdt18165xx: 0.791 pu
# Voltage warning at p1rdt18145-p1rdt18165xx: 0.807 pu
# Voltage warning at p1rdt18145-p1rdt18152xx: 0.798 pu
# Voltage warning at p1rdt18145-p1rdt18152xx: 0.791 pu
# Voltage warning at p1rdt18145-p1rdt18152xx: 0.807 pu
# Voltage warning at p1rdt18145-p1rdt18152x: 0.798 pu
# Voltage warning at p1rdt18145-p1rdt18152x: 0.791 pu
# Voltage warning at p1rdt18145-p1rdt18152x: 0.807 pu
# Voltage warning at p1rdt17688-p1rdt18167x: 0.801 pu
# Voltage warning at p1rdt17688-p1rdt18167x: 0.794 pu
# Voltage warning at p1rdt17688-p1rdt18167x: 0.810 pu
# Voltage warning at p1rdt17516-p1rdt17555x: 0.802 pu
# Voltage warning at p1rdt17516-p1rdt17555x: 0.795 pu
# Voltage warning at p1rdt17516-p1rdt17555x: 0.811 pu
# Voltage warning at p1rdt17504-p1rdt17534x: 0.808 pu
# Voltage warning at p1rdt17504-p1rdt17534x: 0.801 pu
# Voltage warning at p1rdt17504-p1rdt17534x: 0.818 pu
# Voltage warning at p1rdt17542-p1rdt18097xxx: 0.818 pu
# Voltage warning at p1rdt17542-p1rdt18097xxx: 0.810 pu
# Voltage warning at p1rdt17542-p1rdt18097xxx: 0.827 pu
# Voltage warning at p1rdt17542-p1rdt18097xx: 0.816 pu
# Voltage warning at p1rdt17542-p1rdt18097xx: 0.809 pu
# Voltage warning at p1rdt17542-p1rdt18097xx: 0.826 pu
# Voltage warning at p1rdt17542-p1rdt18097x: 0.811 pu
# Voltage warning at p1rdt17542-p1rdt18097x: 0.804 pu
# Voltage warning at p1rdt17542-p1rdt18097x: 0.821 pu
# Voltage warning at p1rdt18105-p1rdt18107xx: 0.818 pu
# Voltage warning at p1rdt18105-p1rdt18107xx: 0.810 pu
# Voltage warning at p1rdt18105-p1rdt18107xx: 0.827 pu
# Voltage warning at p1rdt18105-p1rdt18107x: 0.818 pu
# Voltage warning at p1rdt18105-p1rdt18107x: 0.810 pu
# Voltage warning at p1rdt18105-p1rdt18107x: 0.827 pu
# Voltage warning at p1rdt18102-p1rdt18107x: 0.818 pu
# Voltage warning at p1rdt18102-p1rdt18107x: 0.810 pu
# Voltage warning at p1rdt18102-p1rdt18107x: 0.827 pu
# Voltage warning at p1rdt18102-p1rdt18107xx: 0.818 pu
# Voltage warning at p1rdt18102-p1rdt18107xx: 0.810 pu
# Voltage warning at p1rdt18102-p1rdt18107xx: 0.827 pu
# Voltage warning at p1rdt18080-p1rdt18088x: 0.827 pu
# Voltage warning at p1rdt18080-p1rdt18088x: 0.819 pu
# Voltage warning at p1rdt18080-p1rdt18088x: 0.836 pu
# Voltage warning at p1rdt17176-p1rdt17340xx: 0.842 pu
# Voltage warning at p1rdt17176-p1rdt17340xx: 0.834 pu
# Voltage warning at p1rdt17176-p1rdt17340xx: 0.851 pu
# Voltage warning at p1rdt17176-p1rdt17340x: 0.837 pu
# Voltage warning at p1rdt17176-p1rdt17340x: 0.828 pu
# Voltage warning at p1rdt17176-p1rdt17340x: 0.845 pu
# Voltage warning at p1rdt18031-p1rdt18060x: 0.878 pu
# Voltage warning at p1rdt18031-p1rdt18060x: 0.868 pu
# Voltage warning at p1rdt18031-p1rdt18060x: 0.885 pu
# Voltage warning at p1rdt17605-p1rdt18045x: 0.835 pu
# Voltage warning at p1rdt17605-p1rdt18045x: 0.827 pu
# Voltage warning at p1rdt17605-p1rdt18045x: 0.840 pu
# Voltage warning at p1rdt17605-p1rdt18045xx: 0.823 pu
# Voltage warning at p1rdt17605-p1rdt18045xx: 0.815 pu
# Voltage warning at p1rdt17605-p1rdt18045xx: 0.828 pu
# Voltage warning at p1rdt17605-p1rdt18171x: 0.845 pu
# Voltage warning at p1rdt17605-p1rdt18171x: 0.836 pu
# Voltage warning at p1rdt17605-p1rdt18171x: 0.848 pu
# Voltage warning at p1rdt17605-p1rdt18171x_b1_1: 0.845 pu
# Voltage warning at p1rdt17605-p1rdt18171x_b1_1: 0.836 pu
# Voltage warning at p1rdt17605-p1rdt18171x_b1_1: 0.848 pu
# Voltage warning at p1rdt16500-p1rdt17605x: 0.825 pu
# Voltage warning at p1rdt16500-p1rdt17605x: 0.818 pu
# Voltage warning at p1rdt16500-p1rdt17605x: 0.827 pu
# Voltage warning at p1rdt16500-p1rdt17605xx: 0.816 pu
# Voltage warning at p1rdt16500-p1rdt17605xx: 0.809 pu
# Voltage warning at p1rdt16500-p1rdt17605xx: 0.818 pu
# Voltage warning at p1rdt16494-p1rdt16565x: 0.844 pu
# Voltage warning at p1rdt16494-p1rdt16565x: 0.837 pu
# Voltage warning at p1rdt16494-p1rdt16565x: 0.844 pu
# Voltage warning at p1rdt16665-p1rdt16672x: 0.847 pu
# Voltage warning at p1rdt16665-p1rdt16672x: 0.841 pu
# Voltage warning at p1rdt16665-p1rdt16672x: 0.847 pu
# Voltage warning at p1rdt16665-p1rdt16673x: 0.847 pu
# Voltage warning at p1rdt16665-p1rdt16673x: 0.841 pu
# Voltage warning at p1rdt16665-p1rdt16673x: 0.847 pu
# Voltage warning at p1rdt16497-p1rdt17026x: 0.848 pu
# Voltage warning at p1rdt16497-p1rdt17026x: 0.842 pu
# Voltage warning at p1rdt16497-p1rdt17026x: 0.849 pu
# Voltage warning at p1rdt17025-p1rdt17027x: 0.870 pu
# Voltage warning at p1rdt17025-p1rdt17027x: 0.865 pu
# Voltage warning at p1rdt17025-p1rdt17027x: 0.870 pu
# Voltage warning at p1rdt16361-p1rdt17027x: 0.879 pu
# Voltage warning at p1rdt16361-p1rdt17027x: 0.873 pu
# Voltage warning at p1rdt16361-p1rdt17027x: 0.879 pu
# Voltage warning at p1rdt16998-p1rdt17003x: 0.896 pu
# Voltage warning at p1rdt17642-p1rdt17662x: 0.800 pu
# Voltage warning at p1rdt17642-p1rdt17667x: 0.794 pu
# Voltage warning at p1rdt17642-p1rdt17680x: 0.794 pu
# Voltage warning at p1rdt17643-p1rdt17657xxx: 0.800 pu
# Voltage warning at p1rdt17657-p1rdt17677x: 0.811 pu
# Voltage warning at p1rdt17723-p1rdt17726x: 0.798 pu
# Voltage warning at p1rdt17723-p1rdt17730x: 0.806 pu
# Voltage warning at p1rdt18141-p1rdt18145xxx: 0.807 pu
# Voltage warning at p1rdt17650-p1rdt18165xxx: 0.798 pu
# Voltage warning at p1rdt18133-p1rdt18165xxx: 0.791 pu
# Voltage warning at p1rdt17605-p1rdt18171x_b2_1: 0.844 pu
# Voltage warning at p1rdt17605-p1rdt18171x_b2_1: 0.836 pu
# Voltage warning at p1rdt17605-p1rdt18171x_b2_1: 0.848 pu
# Voltage warning at p1rdt17597-p1rdt17681x: 0.800 pu
# Voltage warning at p1rdt17597-p1rdt17681x: 0.794 pu
# Voltage warning at p1rdt17597-p1rdt17681x: 0.811 pu
# Voltage warning at p1rdm38890: 1.108 pu
# Voltage warning at p1rdm38890: 1.108 pu
# Voltage warning at p1rdm38898: 1.102 pu
# Voltage warning at p1rdm38898: 1.103 pu
# Voltage warning at p1rdm38899: 1.101 pu
# Voltage warning at p1rdm38899: 1.101 pu
# Voltage warning at p1rdm39425: 1.111 pu
# Voltage warning at p1rdm39425: 1.111 pu
# Voltage warning at p1rdm39426: 1.113 pu
# Voltage warning at p1rdm39426: 1.114 pu
# Voltage warning at p1rdm39843: 1.108 pu
# Voltage warning at p1rdm39843: 1.108 pu
# Voltage warning at p1rdm39845: 1.109 pu
# Voltage warning at p1rdm39845: 1.109 pu
# Voltage warning at p1rdm39846: 1.108 pu
# Voltage warning at p1rdm39846: 1.108 pu
# Voltage warning at p1rdm39849: 1.111 pu
# Voltage warning at p1rdm39849: 1.111 pu
# Voltage warning at p1rdm40936: 1.113 pu
# Voltage warning at p1rdm40936: 1.114 pu
# Voltage warning at p1rdm40938: 1.114 pu
# Voltage warning at p1rdm40938: 1.114 pu
# Voltage warning at p1rdt17265-p1rdt17420x: 1.114 pu
# Voltage warning at p1rdt17526-p1rdt17528x: 1.119 pu
# Voltage warning at p1rdt17527-p1rdt17529x: 1.114 pu
# Voltage warning at p1rdt17427-p1rdt18013x: 1.115 pu
# Voltage warning at p1rdt17427-p1rdt18013x: 1.109 pu
# Voltage warning at p1rdt17427-p1rdt18013x: 1.120 pu
# Voltage warning at p1rdt17569-p1rdt17572x: 1.106 pu
# Voltage warning at p1rdt17529_b1_1: 1.106 pu
# Voltage warning at p1rdt17529_b1_1: 1.113 pu
# Voltage warning at p1rdt17526-p1rdt17529x: 1.114 pu
# Voltage warning at p1rdt17526-p1rdt17529x: 1.108 pu
# Voltage warning at p1rdt17526-p1rdt17529x: 1.119 pu
# Voltage warning at p1rdt17420_b1_1: 1.114 pu
# Voltage warning at p1rdt17420_b1_1: 1.109 pu
# Voltage warning at p1rdt17420_b1_1: 1.120 pu
# Voltage warning at p1rdt17529_b2_1: 1.106 pu
# Voltage warning at p1rdt17529_b2_1: 1.113 pu
# Voltage warning at p1rdt17420_b2_1: 1.114 pu
# Voltage warning at p1rdt17420_b2_1: 1.109 pu
# Voltage warning at p1rdt17420_b2_1: 1.120 pu
# Voltage warning at p1rdm42899: 0.879 pu
# Voltage warning at p1rdm42899: 0.880 pu
# Voltage warning at p1rdm42901: 0.874 pu
# Voltage warning at p1rdm42901: 0.875 pu
# Voltage warning at p1rdm42900: 0.867 pu
# Voltage warning at p1rdm42900: 0.869 pu
# Voltage warning at p1rdm42903: 0.867 pu
# Voltage warning at p1rdm42903: 0.868 pu
# Voltage warning at p1rdm42902: 0.877 pu
# Voltage warning at p1rdm42902: 0.878 pu
# Voltage warning at p1rdm42907: 0.899 pu
# Voltage warning at p1rdm42907: 0.900 pu
# Voltage warning at p1rdm42911: 0.895 pu
# Voltage warning at p1rdm42911: 0.896 pu
# Voltage warning at p1rdm42908: 0.894 pu
# Voltage warning at p1rdm42908: 0.895 pu
# Voltage warning at p1rdm42927: 0.863 pu
# Voltage warning at p1rdm42927: 0.865 pu
# Voltage warning at p1rdm42926: 0.849 pu
# Voltage warning at p1rdm42926: 0.850 pu
# Voltage warning at p1rdm42935: 0.840 pu
# Voltage warning at p1rdm42935: 0.842 pu
# Voltage warning at p1rdm42923: 0.836 pu
# Voltage warning at p1rdm42923: 0.838 pu
# Voltage warning at p1rdm42930: 0.832 pu
# Voltage warning at p1rdm42930: 0.834 pu
# Voltage warning at p1rdm42936: 0.837 pu
# Voltage warning at p1rdm42936: 0.838 pu
# Voltage warning at p1rdm42931: 0.872 pu
# Voltage warning at p1rdm42931: 0.874 pu
# Voltage warning at p1rdm42924: 0.865 pu
# Voltage warning at p1rdm42924: 0.867 pu
# Voltage warning at p1rdm42922: 0.860 pu
# Voltage warning at p1rdm42922: 0.861 pu
# Voltage warning at p1rdm42929: 0.857 pu
# Voltage warning at p1rdm42929: 0.858 pu
# Voltage warning at p1rdm42945: 0.869 pu
# Voltage warning at p1rdm42945: 0.870 pu
# Voltage warning at p1rdm42946: 0.869 pu
# Voltage warning at p1rdm42946: 0.870 pu
# Voltage warning at p1rdm42951: 0.888 pu
# Voltage warning at p1rdm42951: 0.889 pu
# Voltage warning at p1rdm42967: 0.878 pu
# Voltage warning at p1rdm42967: 0.879 pu
# Voltage warning at p1rdm42970: 0.878 pu
# Voltage warning at p1rdm42970: 0.879 pu
# Voltage warning at p1rdm42971: 0.877 pu
# Voltage warning at p1rdm42971: 0.878 pu
# Voltage warning at p1rdm43485: 0.898 pu
# Voltage warning at p1rdm43485: 0.898 pu
# Voltage warning at p1rdm43483: 0.894 pu
# Voltage warning at p1rdm43483: 0.894 pu
# Voltage warning at p1rdm44216: 0.897 pu
# Voltage warning at p1rdm44216: 0.898 pu
# Voltage warning at p1rdm44215: 0.891 pu
# Voltage warning at p1rdm44215: 0.892 pu
# Voltage warning at p1rdm44213: 0.900 pu
# Voltage warning at p1rdt18979-p1rdt18985x: 0.897 pu
# Voltage warning at p1rdt19380-p1rdt19382x: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382x: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382x: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xxx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xxx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xxx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xxxx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xxxx: 0.000 pu
# Voltage warning at p1rdt19380-p1rdt19382xxxx: 0.000 pu

# %% [markdown]
# ### Print circuit loads

# %%
# Get total losses
losses = dss.Circuit.Losses()
total_loss_kw = losses[0] / 1000  # Convert watts to kW          
# Get total circuit power 
total_circuit_power = dss.Circuit.TotalPower() #  sum of all the powers in the first terminal of each source (Vsource and Isource)
total_circuit_power_kw = - total_circuit_power[0]  # Real power in kW          
# Total load
total_circuit_Loads = total_circuit_power_kw -total_loss_kw

print(f'Total circuit load: {total_circuit_Loads} kw')
# Out:
# Total circuit load: 50400.27587415851 kw

# %% [markdown]
# ### Print line and transformer data

# %%
# print("Line Information:")
# display(all_line_df.head(10))
# print("\nTransformer Information:")
# display(all_transformer_df.head(10))

top_10_loading = all_line_df.nlargest(10, 'Loading [%]')
display(top_10_loading)
top_10_loading = all_transformer_df.nlargest(10, 'Loading [%]')
display(top_10_loading)
# Out:
#        Weather year                                         Line  \
# 14821             0             breaker(r:rhs0_69-rts0_69)r_9274
# 11205             0                       l(r:rdm3431-rdt2033lv)
# 13715             0                         l(r:rdt2712-rdt2716)
# 14350             0           padswitch(r:rdt2712-rdt2716)r_9239
# 14349             0           padswitch(r:rdt2716-rdt2728)r_9238
# 13714             0                         l(r:rdt2716-rdt2728)
# 9247              0  recloser_disswitch(r:rdt1548-rdt1926)r_9925
# 14345             0           padswitch(r:rdt2717-rdt2718)r_9234
# 13712             0                         l(r:rdt2717-rdt2718)
# 14344             0           padswitch(r:rdt2717-rdt2718)r_9233
#
#                     LineCode  Length [km]   From_Lat     To_Lat  From_Long  \
# 14821            breaker_3_3     0.001000  36.198024  36.199176 -79.613022
# 11205  1p_oh_al_2/0_rucina_2     0.017970  36.189869  36.189866 -79.565413
# 13715             3p_ug_al_3     0.076106  36.171453  36.171554 -79.701693
# 14350            padswitch_3     0.001000  36.171494  36.171453 -79.701722
# 14349            padswitch_3     0.001000  36.171607  36.171651 -79.701059
# 13714             3p_ug_al_3     0.009974  36.171626  36.171607 -79.701185
# 9247              recloser_3     0.001000  36.198899  36.198926 -79.629506
# 14345            padswitch_3     0.001000  36.172059  36.172078 -79.700425
# 13712             3p_ug_al_3     0.039816  36.171855  36.172059 -79.700752
# 14344            padswitch_3     0.001000  36.171838  36.171855 -79.700804
#
#          To_Long  NormAmps [A]  Nominal V [kV]  Voltage [pu]  Loading [%]
# 14821 -79.612539        115.08       39.837169      0.990561   180.554722
# 11205 -79.565618        115.08        0.120089      0.990575   157.073771
# 13715 -79.701149        295.19        7.199558      1.017741   155.399856
# 14350 -79.701693        295.19        7.199558      1.017826   155.394473
# 14349 -79.701051        295.19        7.199558      1.015524   154.338375
# 13714 -79.701059        295.19        7.199558      1.015759   154.338375
# 9247  -79.629550        115.08        7.199558      0.969136   154.279732
# 14345 -79.700477        295.19        7.199558      1.013540   153.944229
# 13712 -79.700425        295.19        7.199558      1.014489   153.944229
# 14344 -79.700752        295.19        7.199558      1.014572   153.941422
#       Weather year              Transformer      Bus        Lat       Long  \
# 2943             0  tr(r:rdt2616-rdt2616lv)  rdt2616  36.175936 -79.690517
# 413              0    tr(r:rdt442-rdt442lv)   rdt442  36.259067 -79.595789
# 2397             0  tr(r:rdt2278-rdt2278lv)  rdt2278  36.155852 -79.531618
# 2655             0    tr(r:rdt891-rdt891lv)   rdt891  36.220909 -79.536084
# 1855             0  tr(r:rdt1674-rdt1674lv)  rdt1674  36.204917 -79.650466
# 851              0    tr(r:rdt846-rdt846lv)   rdt846  36.229314 -79.598585
# 2789             0  tr(r:rdt1247-rdt1247lv)  rdt1247  36.186446 -79.532400
# 463              0    tr(r:rdt492-rdt492lv)   rdt492  36.263092 -79.553846
# 472              0    tr(r:rdt501-rdt501lv)   rdt501  36.254993 -79.561753
# 3029             0  tr(r:rdt2702-rdt2702lv)  rdt2702  36.170523 -79.705730
#
#       Num windings  Num phases     KV rating [kV]  kVA rating [kVA]  \
# 2943             3           1  [7.2, 0.12, 0.12]              9.25
# 413              3           1  [7.2, 0.12, 0.12]              9.25
# 2397             3           1  [7.2, 0.12, 0.12]              9.25
# 2655             3           1  [7.2, 0.12, 0.12]              9.25
# 1855             3           1  [7.2, 0.12, 0.12]             23.12
# 851              3           1  [7.2, 0.12, 0.12]             23.12
# 2789             3           1  [7.2, 0.12, 0.12]             23.12
# 463              3           1  [7.2, 0.12, 0.12]              9.25
# 472              3           1  [7.2, 0.12, 0.12]              9.25
# 3029             3           1  [7.2, 0.12, 0.12]              9.25
#
#       Loading [%]                                      Voltages [kV]
# 2943   226.600961  [7.1396364942587525, 0.08461940365907238, 0.0,...
# 413    217.807108  [7.089585215904905, -0.15570370205626458, 0.0,...
# 2397   209.478191  [6.822762811562537, -0.036643114091011356, 0.0...
# 2655   202.776830  [7.116687161580037, -0.034769035396885445, 0.0...
# 1855   188.554189  [6.860811437767339, 0.0834496995405292, 0.0, 0...
# 851    184.540425  [6.886479930482205, -0.15654948795329768, 0.0,...
# 2789   182.439490  [7.317021490757943, -0.15367456904004675, 0.0,...
# 463    181.842075  [7.377151103643927, -0.03864896602420429, 0.0,...
# 472    181.403519  [7.484212661384709, 0.08218369067746516, 0.0, ...
# 3029   179.925642  [7.374260321095433, 0.0851211243355416, 0.0, 0...

# %% [markdown]
# ## Load saved PF data

# %%
# --- Save results ---     
lines_file_name = f"lines_regional_peak"
transformers_file_name = f"transformers_regional_peak"
metadata_file_name = f"metadata_regional_peak"

city = 'GSO'
region = 'rural'

TGW_weather_year = '2018'
TGW_scenario = 'historical'
predictions_dir = os.path.join(output_pf_path, f"{city}/{region}/{TGW_scenario}/{TGW_weather_year}/")
lines_dict_1 = joblib.load(os.path.join(predictions_dir, f"{lines_file_name}.joblib"))
transformers_dict_1 = joblib.load(os.path.join(predictions_dir, f"{transformers_file_name}.joblib"))

TGW_weather_year = '2058'
TGW_scenario = 'rcp45hotter'
predictions_dir = os.path.join(output_pf_path, f"{city}/{region}/{TGW_scenario}/{TGW_weather_year}/")
lines_dict_2 = joblib.load(os.path.join(predictions_dir, f"{lines_file_name}.joblib"))
transformers_dict_2 = joblib.load(os.path.join(predictions_dir, f"{transformers_file_name}.joblib"))

# TGW_weather_year = '2058'
# TGW_scenario = 'rcp45cooler'
# predictions_dir = os.path.join(output_pf_path, f"{city}/{region}/{TGW_scenario}/{TGW_weather_year}/")
# lines_dict_3 = joblib.load(os.path.join(predictions_dir, f"{lines_file_name}.joblib"))
# transformers_dict_3 = joblib.load(os.path.join(predictions_dir, f"{transformers_file_name}.joblib"))

lines_dict = lines_dict_1
transformers_dict = transformers_dict_1
lines_dict.update(lines_dict_2)
transformers_dict.update(transformers_dict_2)
# lines_dict.update(lines_dict_3)
# transformers_dict.update(transformers_dict_3)

# %%
lines_dict.keys()
# Out:
# dict_keys([('2018', 'historical'), ('2058', 'rcp45hotter')])

# %%
lines_dict[('2018', 'historical')].keys()
# Out:
# dict_keys([('2018', 'GSO', 'rural')])

# %%
lines_dict[('2018', 'historical')][('2018', 'GSO', 'rural')].head(2)
# Out:
#    Weather year              Line        LineCode  Length [km]   From_Lat  \
# 0             0  sb1_rhs1_1247_35    3p_oh_code_3     0.001512  36.269344
# 1             0  sb1_rhs1_1247_33  breaker_13kv_3     0.001000  36.269576
#
#       To_Lat  From_Long    To_Long  NormAmps [A]  Nominal V [kV]  \
# 0  36.269244 -79.611706 -79.611329         480.0        7.199558
# 1  36.269481 -79.611155 -79.611157        1200.0        7.199558
#
#    Voltage [pu]  Loading [%]
# 0      1.024671   104.818707
# 1      1.024851    41.927482

# %% [markdown]
# ## Train regression models for demand forecasting
#
# This script trains regression models using
# - **Weather data** (past & future)
# - **Demand data** (past observations)
#
# to predict demand based on:
# - **Weather data** (future)
#
# Models to consider: MLP, linear regression, polynomial regression (4th degree from Dessler’s talk), long short-term memory, Random Forest, Support Vector Regression

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pyarrow.parquet as pq
import joblib
import scipy
import pandas as pd
import time
import os
import re
import glob
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import sklearn
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPRegressor as MLP
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from datetime import datetime, timedelta
import seaborn as sns
import pytz
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
import yaml
import pprint
import pwlf

from src import input_ops
from src import model_ops

# %% [markdown]
# ### Load config file with scenarios and parameters

# %%
config_file_name = 'config1'; config_path = f"config/{config_file_name}.yaml"; config = input_ops.load_config(config_path)

aggregation_level = config['aggregation_level']
smart_ds_year = config['smart_ds_years'][0]
building_types = config["building_types"]
input_data_dict_name = config['input_data_dict_name']
Y_column = config['Y_column']
X_columns = config['X_columns']

## Initialize parameters for saving paths
output_path_str = config['output_data_training_path']
aggregation_level = config['aggregation_level']

if Y_column == 'cooling_kw_sum':
    prediction_model_str = config['prediction_model_cooling']
elif Y_column == 'heating_kw':
    prediction_model_str = config['prediction_model_heating']
else:
    raise ValueError('Model architecture is not defined for model output! (only for cooling_sum and heating)')
    
# pprint.pprint(config, sort_dicts=False) # print config
print(f"Aggregation level: {config['aggregation_level']} \n SMART-DS year: {config['smart_ds_years'][0]} \n Months: {config['start_month']}-{config['end_month']} \n output: {config['Y_column']}, \n inputs: {config['X_columns_set']} \n Prediction model: {prediction_model_str} \n output directory:{config['output_data_training_path']}")
# Out:
# Aggregation level: feeder
#  SMART-DS year: 2018
#  Months: 1-12
#  output: cooling_kw_sum,
#  inputs: X_columns_D
#  Prediction model: MLP_2_512_64
#  output directory:/nfs/turbo/seas-mtcraig-climate/Aviad/load_prediction/results/data/training/2018/months_1_12/ml_output_data/cooling_kw_sum/X_columns_D/feeder/

# %% [markdown]
# ### Load input data (Resstock weather data & smart-ds load data)

# %%
## Load input load & weather data of year-city-region-building_type combinations
loaded_input_data_dict = {}
if config['aggregation_level'] == 'building': # Assuming buildings have separate joblib files
    for city, region in CITY_REGIONS_TO_RUN.items():
        path_temp = os.path.join(config["input_data_training_path"], f"{city}/{region}/{input_data_dict_name}.joblib")
        print(path_temp)
        # loaded_input_data_dict[(smart_ds_year,city,region,load_model,building_types)] = joblib.load(os.path.join(config["input_data_training_path"], f"{city}/{region}/{input_data_dict_name}.joblib"))
else:
    print(f'Loading dictionary with load & weather data from {config["input_data_training_path"]}')
    loaded_input_data_dict = joblib.load(os.path.join(config["input_data_training_path"], f"{input_data_dict_name}.joblib")) # Load dictionary with load & weather data
# Out:
# Loading dictionary with load & weather data from /nfs/turbo/seas-mtcraig-climate/Aviad/load_prediction/results/data/training/2018/months_1_12/ml_input_data/resstock/amy2018/feeder/

# %% [markdown]
# ### Train ML models and save models, scalers and metrics
# ---

# %%
## Train MLP model for year-city-region-building_type combinations
start_time = time.time()

## Initialize dictionaries
mlp_results = {} # change to mlp_metrics_dict
mlp_model_dict = {}
xnorm_dict = {}
ynorm_dict = {}

for smart_ds_year, city, region, load_model, building_type in loaded_input_data_dict.keys():
    print(f".......Training {prediction_model_str} for {smart_ds_year} {city} {region} {load_model} {building_type}.......")
    # Train MLP model

    # Load data
    if not config['aggregation_level'] == 'building':
        input_df = loaded_input_data_dict[(smart_ds_year, city, region, load_model, building_type)]
    else:
        print("To train model at the building level: (1) create processed input data at the building level, and (2) update code here to load it")

    match prediction_model_str:
        case 'MLP_2_1452_10':
            first_L_n = 1452
            second_L_n = 10
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)
        case 'MLP_2_4096_512': 
            first_L_n = 2048
            second_L_n = 256
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n) 
        case 'MLP_2_2048_512': 
            first_L_n = 4096
            second_L_n = 512
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)    
        case 'MLP_2_1024_128': 
            first_L_n = 1024
            second_L_n = 128
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)
        case 'MLP_2_512_64': 
            first_L_n = 512
            second_L_n = 64
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)
        case 'MLP_2_256_32':
            first_L_n = 256
            second_L_n = 32
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)
        case 'MLP_2_100_10':
            first_L_n = 100
            second_L_n = 10
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)
        case 'MLP_2_32_16':
            first_L_n = 32
            second_L_n = 16
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)
        case 'MLP_1_16':
            first_L_n = 16
            second_L_n = ''
            MLP_model, xnorm, ynorm, y_test, y_test_pred, y_train, y_train_pred, training_runtime = model_ops.train_mlp_model(input_df, X_columns, Y_column, first_L_n, second_L_n)
        case 'PWLR_4bp':
            # X_columns = ['Dry Bulb Temperature [°C]']
            MLP_model, xnorm, ynorm, y_test, y_test_pred, training_runtime = model_ops.train_piecewise_linear_model(input_df, X_columns, Y_column, num_breakpoints=4)
        case 'Poly_4deg':
            MLP_model, poly_transform, xnorm, ynorm, y_test, y_test_pred, training_runtime = model_ops.train_polynomial_model(input_df, X_columns, Y_column, degree=4, alpha=1.0)
        case _:
            MLP_model, xnorm, ynorm, y_test, y_test_pred, training_runtime = model_ops.train_linear_model(input_df, X_columns, Y_column)

    # compute MLP performance metrics
    r2, mae, mape, rmse, nrmse, peak_load_error, peak_time_error, mape_high, nrmse_high = model_ops.metrics_test_data(y_test, y_test_pred)

    # Save MLP performance metrics
    mlp_results[(smart_ds_year, city, region, load_model, building_type)] = {
        "X_columns": X_columns,
        "Y_column": Y_column,
        "training_runtime": training_runtime,
        "y_test": y_test, 
        "y_test_pred": y_test_pred,
        "y_train": y_train, 
        "y_train_pred": y_train_pred,
        "r2": r2,
        "mae": mae,
        "mape": mape,
        "rmse": rmse,
        "nrmse": nrmse,
        "peak_load_error": peak_load_error,
        "peak_time_error": peak_time_error,
        "mape_high": mape_high,
        "nrmse_high": nrmse_high
    }
    
    # Save trained models and scalers in dictionaries
    mlp_model_dict[(smart_ds_year, city, region, load_model, building_type)] = MLP_model
    xnorm_dict[(smart_ds_year, city, region, load_model, building_type)] = xnorm
    ynorm_dict[(smart_ds_year, city, region, load_model, building_type)] = ynorm

# Save dictionaries as joblib files
joblib.dump(mlp_results, os.path.join(output_path_str, "metrics", f"{prediction_model_str}_results.joblib"))
joblib.dump(mlp_model_dict, os.path.join(output_path_str, "models", f"{prediction_model_str}_models_dict.joblib"))
joblib.dump(xnorm_dict, os.path.join(output_path_str, "scalers", f"{prediction_model_str}_xnorm_dict.joblib"))
joblib.dump(ynorm_dict, os.path.join(output_path_str, "scalers", f"{prediction_model_str}_ynorm_dict.joblib"))

print("All models, scalers, and results saved successfully!")

end_time = time.time(); print(f"Runtime for Training models: {(end_time - start_time) / 60:.2f} minutes")
# Out:
# .......Training MLP_1_16 for 2018 GSO rural rhs2_1247--rdt1262 res.......
# .......Training MLP_1_16 for 2018 GSO rural rhs2_1247--rdt1262 com.......
# .......Training MLP_1_16 for 2018 GSO rural rhs2_1247--rdt1264 res.......
# .......Training MLP_1_16 for 2018 GSO rural rhs2_1247--rdt1264 com.......
# .......Training MLP_1_16 for 2018 GSO rural rhs0_1247--rdt1527 res.......
# .......Training MLP_1_16 for 2018 GSO rural rhs0_1247--rdt1527 com.......
# .......Training MLP_1_16 for 2018 GSO rural rhs0_1247--rdt1948 res.......
# .......Training MLP_1_16 for 2018 GSO rural rhs0_1247--rdt1948 com.......
# .......Training MLP_1_16 for 2018 GSO rural rhs0_1247--rdt1534 res.......
# .......Training MLP_1_16 for 2018 GSO rural rhs0_1247--rdt1534 com.......
# .......Training MLP_1_16 for 2018 GSO rural rhs1_1247--rdt137 res.......
# .......Training MLP_1_16 for 2018 GSO rural rhs1_1247--rdt137 com.......
# .......Training MLP_1_16 for 2018 GSO rural rhs3_1247--rdt2999 com.......
# .......Training MLP_1_16 for 2018 GSO rural rhs3_1247--rdt2705 res.......
# .......Training MLP_1_16 for 2018 GSO rural rhs3_1247--rdt2705 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt785 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt785 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt1106 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt1380 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt1380 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt486 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt486 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt1528 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt1528 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt898 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs2_1247--idt898 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt275 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt275 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt194 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt1592 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt1592 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt1687 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt1687 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt1682 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs4_1247--idt1682 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt620 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt620 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt605 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt740 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt740 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt999 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt999 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs0_1247--idt629 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt1289 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt1210 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt1439 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt1439 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt670 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt670 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt1478 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt1478 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs1_1247--idt1485 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs5_1247--idt627 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt226 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt226 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt1010 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt1010 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt893 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt893 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt960 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt960 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt1153 com.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt1334 res.......
# .......Training MLP_1_16 for 2018 GSO industrial ihs3_1247--idt1334 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs11_1247--udt8110 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs11_1247--udt8110 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs11_1247--p1umv22 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs11_1247--udt7105 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs11_1247--udt7105 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs8_1247--udt12494 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs8_1247--udt12494 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs8_1247--udt7252 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs8_1247--udt7252 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs6_1247--udt10788 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs6_1247--udt10788 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs6_1247--udt9964 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs6_1247--udt9964 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs6_1247--udt6570 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs6_1247--udt6570 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt15482 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt15482 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt17650 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt17650 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt1278 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt1278 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt15805 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs12_1247--udt15805 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs1_1247--udt15926 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs1_1247--udt15926 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs1_1247--udt20176 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs1_1247--udt20176 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs3_1247--udt1582 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs3_1247--udt1582 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs3_1247--udt1571 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs3_1247--udt1571 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs3_1247--udt1567 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs3_1247--udt1567 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs14_1247--udt5493 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs14_1247--udt5493 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs14_1247--udt12226 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs14_1247--udt12226 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs14_1247--udt11665 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs14_1247--udt11665 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs16_1247--udt310 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs16_1247--udt310 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs16_1247--udt15512 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs16_1247--udt15512 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs13_1247--udt4015 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs13_1247--udt4015 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs13_1247--udt4819 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs13_1247--udt4819 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt14110 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt14110 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt16813 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt16813 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt11456 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt11456 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt2508 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt2508 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs9_1247--udt13714 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs0_1247--udt12274 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs0_1247--udt12274 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs0_1247--udt16115 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs0_1247--udt16115 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs0_1247--udt14717 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs0_1247--udt14717 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs15_1247--udt20824 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs15_1247--udt20824 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs15_1247--udt19670 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs15_1247--udt19670 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs2_1247--udt9312 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs2_1247--udt9312 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs2_1247--udt10746 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs2_1247--udt10746 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs2_1247--udt12473 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs2_1247--udt12473 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs19_1247--udt19872 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs19_1247--udt19872 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs19_1247--udt15839 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs10_1247--udt11713 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs10_1247--udt11713 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs10_1247--udt13528 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs10_1247--udt13528 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs10_1247--udt12084 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs10_1247--udt12084 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs7_1247--udt9675 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs7_1247--udt9675 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs7_1247--udt9662 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs7_1247--udt9662 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs7_1247--udt15849 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs7_1247--udt15849 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs20_1247--udt8894 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs20_1247--udt8894 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs20_1247--udt5173 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs20_1247--udt5173 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs20_1247--udt9897 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs20_1247--udt9897 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs18_1247--udt17294 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs18_1247--udt17294 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs18_1247--udt11616 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs18_1247--udt11616 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs18_1247--udt13374 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs18_1247--udt13374 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs17_1247--udt6592 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs17_1247--udt6592 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs17_1247--udt9551 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs17_1247--udt9551 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt159 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt159 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt20368 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt20368 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt19869 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt19869 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt18558 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs5_1247--udt18558 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--udt12982 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--udt12982 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--p1umv8 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--p1umv8 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--udt11389 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--udt11389 com.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--p1umv7 res.......
# .......Training MLP_1_16 for 2018 GSO urban-suburban uhs4_1247--p1umv7 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt8207 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt8207 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt2378 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt2378 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt8208 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt8208 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt2874 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt2874 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt3467 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs3_1247--p1rdt3467 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs6_1247--p1rdt6561 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs6_1247--p1rdt6561 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs6_1247--p1rdt476 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs6_1247--p1rdt476 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt3039 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt3039 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt4805 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt4805 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt3426 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt3426 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt1528 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs2_1247--p1rdt1528 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs0_1247--p1rdt6854 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs0_1247--p1rdt6854 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs0_1247--p1rdt5663 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs0_1247--p1rdt5663 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt5481 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt5481 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt2300 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt2300 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt5185 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt5185 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt6999 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt6999 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt5851 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt5851 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt4715 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs4_1247--p1rdt4715 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt2397 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt2397 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt5979 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt5979 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt6578 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt6578 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt6634 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs1_1247--p1rdt6634 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt8064 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt8064 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt1339 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt1339 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt7748 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt7748 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt7147 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs5_1247--p1rdt7147 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs7_1247--p1rdt1161 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs7_1247--p1rdt1161 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs7_1247--p1rdt7669 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs7_1247--p1rdt7669 com.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs7_1247--p1rdt1291 res.......
# .......Training MLP_1_16 for 2018 AUS P1R p1rhs7_1247--p1rdt1291 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs0_1247--p1udt12703 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs0_1247--p1udt12703 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs0_1247--p1udt22170 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs0_1247--p1udt22170 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs0_1247--p1udt2142 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs0_1247--p1udt2142 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt18369 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt18369 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt9621 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt9621 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt899 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt899 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt18962 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt18962 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt8846 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt8846 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt18580 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs2_1247--p1udt18580 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt16446 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt16446 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt10621 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt10621 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt2578 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt2578 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt1456 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs20_1247--p1udt1456 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt20692 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt387 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt387 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt21523 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt21523 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt25123 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt25123 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt22325 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt22325 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt6854 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt6854 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt19234 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt19234 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt13121 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt13121 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt22357 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt20546 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt20546 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt13187 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt13187 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt21819 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt21819 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt20362 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt20362 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt4409 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs9_1247--p1udt4409 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt6863 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt6863 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt24624 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt24624 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt20099 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt20099 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt24311 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs22_1247--p1udt24311 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs14_1247--p1udt21168 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs14_1247--p1udt21168 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs14_1247--p1udt6143 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs14_1247--p1udt9467 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs14_1247--p1udt9467 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs14_1247--p1udt7899 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs14_1247--p1udt7899 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs15_1247--p1udt9658 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs15_1247--p1udt9658 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs15_1247--p1udt17622 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs15_1247--p1udt17622 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs15_1247--p1udt2795 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs15_1247--p1udt2795 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt10118 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt10118 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt8187 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt3522 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt3522 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt21698 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt12530 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs13_1247--p1udt12530 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt20878 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt20878 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt22980 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt22980 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt6120 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt6120 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt12591 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt12591 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt14394 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs10_1247--p1udt14394 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs18_1247--p1udt20846 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs18_1247--p1udt20846 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs18_1247--p1udt6910 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs18_1247--p1udt6910 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs18_1247--p1udt15617 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs18_1247--p1udt15617 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs11_1247--p1udt12111 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs11_1247--p1udt12111 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs11_1247--p1udt22445 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs11_1247--p1udt25287 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs11_1247--p1udt25287 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs1_1247--p1udt10929 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs1_1247--p1udt10929 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs1_1247--p1udt14149 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs1_1247--p1udt14149 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs1_1247--p1udt138 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs1_1247--p1udt138 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs3_1247--p1udt6119 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs3_1247--p1udt13260 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs3_1247--p1udt13260 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt5257 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt5257 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt20780 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt20780 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt11662 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt11662 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt16206 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs21_1247--p1udt16206 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs4_1247--p1udt21090 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs4_1247--p1udt21090 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs4_1247--p1udt7282 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs4_1247--p1udt7282 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs19_1247--p1udt17263 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs19_1247--p1udt17263 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs19_1247--p1udt14631 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs19_1247--p1udt14631 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs6_1247--p1udt322 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs6_1247--p1udt322 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs6_1247--p1udt14764 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs6_1247--p1udt14764 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs6_1247--p1udt7653 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs5_1247--p1udt19613 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs5_1247--p1udt19613 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs5_1247--p1udt13240 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs5_1247--p1udt13240 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs5_1247--p1udt21449 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs5_1247--p1udt21449 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt11006 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt11006 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt16473 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt16473 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt7988 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt7988 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt22164 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs16_1247--p1udt22164 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs8_1247--p1udt22258 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs8_1247--p1udt22258 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs8_1247--p1udt4671 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs8_1247--p1udt4671 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs8_1247--p1udt2544 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs8_1247--p1udt2544 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs23_1247--p1udt25139 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs23_1247--p1udt25139 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs23_1247--p1udt21301 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs23_1247--p1udt21301 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs7_1247--p1udt14301 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs7_1247--p1udt14301 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs7_1247--p1udt1702 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs7_1247--p1udt1702 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs17_1247--p1udt19976 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs17_1247--p1udt19976 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs17_1247--p1udt1947 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs17_1247--p1udt1947 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs17_1247--p1udt21587 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs17_1247--p1udt21587 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt8950 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt8950 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt11164 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt11164 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt23696 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt23696 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt8568 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt8568 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt14325 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt14325 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt23867 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs12_1247--p1udt23867 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs24_1247--p1umv22 res.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs24_1247--p1umv22 com.......
# .......Training MLP_1_16 for 2018 AUS P1U p1uhs24_1247--p1umv26 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt5729 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt5729 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt7967 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt7967 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt4732 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt4732 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt3455 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs11_1247--p2udt3455 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs7_1247--p2udt2957 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs7_1247--p2udt2957 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs7_1247--p2udt3821 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs7_1247--p2udt3821 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs9_1247--p2udt5858 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs9_1247--p2udt3884 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs9_1247--p2udt3884 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs9_1247--p2udt3330 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs9_1247--p2udt3330 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs9_1247--p2udt8056 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs9_1247--p2udt8056 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt8082 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt8082 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt7925 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt7925 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt8516 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt8516 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt106 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt106 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt8512 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt8512 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt3567 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs2_1247--p2udt3567 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs8_1247--p2udt6424 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs8_1247--p2udt6424 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs8_1247--p2udt6561 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs8_1247--p2udt5538 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs8_1247--p2udt5538 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs8_1247--p2udt4184 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs8_1247--p2udt4184 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt7573 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt7573 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt8180 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt8180 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt5265 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt5265 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt3496 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt3496 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt7735 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt7735 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt433 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs4_1247--p2udt433 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt3740 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt3740 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt4740 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt4740 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt3475 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt3475 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt7154 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt7154 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt3615 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs1_1247--p2udt3615 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs6_1247--p2udt1124 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs6_1247--p2udt1124 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs6_1247--p2udt6420 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs6_1247--p2udt6420 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs3_1247--p2udt8444 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs3_1247--p2udt8444 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs3_1247--p2udt5611 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs3_1247--p2udt5611 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs12_1247--p2udt5984 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs12_1247--p2udt5984 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs12_1247--p2udt5222 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs12_1247--p2udt5222 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt1587 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt1587 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt4999 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8122 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8122 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt2514 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt2514 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8249 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8249 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8625 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8625 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8078 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs0_1247--p2udt8078 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs5_1247--p2udt7295 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs5_1247--p2udt7295 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs5_1247--p2udt2008 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs5_1247--p2udt2008 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs5_1247--p2udt7035 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs5_1247--p2udt7035 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt8615 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt8615 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt7514 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt7514 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt7412 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt7412 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt8564 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt8564 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt3516 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt3516 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt7118 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs10_1247--p2udt7118 com.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs13_1247--p2udt6883 res.......
# .......Training MLP_1_16 for 2018 AUS P2U p2uhs13_1247--p2udt6883 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt15074 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt15074 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt12515 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt12515 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt12867 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt12867 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt13096 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs23_1247--p1rdt13096 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs19_1247--p1rdt6337 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs19_1247--p1rdt13869 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs19_1247--p1rdt13869 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs19_1247--p1rdt12607 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs19_1247--p1rdt12607 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs3_1247--p1rdt19902 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs3_1247--p1rdt19353 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs3_1247--p1rdt19353 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs3_1247--p1rdt19464 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs3_1247--p1rdt19464 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt2998 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt2998 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt3022 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt3022 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt4002 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt4002 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt2995 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs6_1247--p1rdt2995 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19970 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19970 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19877 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19877 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19568 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19568 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19769 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19769 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19224 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs2_1247--p1rdt19224 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs20_1247--p1rdt10307 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs20_1247--p1rdt10307 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs20_1247--p1rdt6596 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs20_1247--p1rdt6596 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs20_1247--p1rdt11280 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs20_1247--p1rdt11280 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt2463 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt2443 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt2443 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt2464 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt2464 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt2474 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt2474 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt1408 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs10_1247--p1rdt1408 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt6127 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt6127 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt5446 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt5446 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt5466 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt5466 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt8175 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt8175 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt8733 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs8_1247--p1rdt8733 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt13426 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt13426 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt10626 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt10626 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt9125 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt9125 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt10206 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs24_1247--p1rdt10206 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs17_1247--p1rdt4602 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs17_1247--p1rdt4602 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs17_1247--p1rdt4603 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs17_1247--p1rdt4603 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs14_1247--p1rdt3303 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs11_1247--p1rdt1833 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs11_1247--p1rdt1833 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs11_1247--p1rdt1615 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs11_1247--p1rdt1615 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs11_1247--p1rdt1845 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs11_1247--p1rdt1845 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs28_1247--p1rdt11665 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs28_1247--p1rdt12277 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs28_1247--p1rdt12597 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs28_1247--p1rdt12597 com.......
# ...
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs27_1247--p1rdt12171 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs27_1247--p1rdt13779 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs27_1247--p1rdt13779 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs27_1247--p1rdt10622 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs27_1247--p1rdt10622 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rmv3 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17866 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17582 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17582 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt16878 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt16878 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt16899 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt16899 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17784 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17785 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17797 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17711 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17711 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs1_1247--p1rdt17687 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs12_1247--p1rdt3073 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs12_1247--p1rdt3073 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs12_1247--p1rdt3775 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs12_1247--p1rdt3775 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs12_1247--p1rdt4095 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs12_1247--p1rdt4095 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt7218 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt7218 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt7510 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt7510 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt13798 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt13798 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt12732 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs25_1247--p1rdt12732 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs22_1247--p1rdt12023 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs22_1247--p1rdt12023 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs22_1247--p1rdt11230 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs22_1247--p1rdt11230 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt348 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt348 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt1011 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt1011 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt778 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt778 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt1224 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt1224 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt204 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt204 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt25 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs5_1247--p1rdt25 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs26_1247--p1rdt13367 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs26_1247--p1rdt13367 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs26_1247--p1rdt10569 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs26_1247--p1rdt10569 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs26_1247--p1rdt11700 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs26_1247--p1rdt11700 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs7_1247--p1rdt6488 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs7_1247--p1rdt6488 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs7_1247--p1rdt5342 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs7_1247--p1rdt5342 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs7_1247--p1rdt8583 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs7_1247--p1rdt8583 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs7_1247--p1rdt7711 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs16_1247--p1rdt3521 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs16_1247--p1rdt3521 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs9_1247--p1rdt592 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs9_1247--p1rdt592 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs9_1247--p1rdt610 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs9_1247--p1rdt610 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt11804 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt11804 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt11118 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt11118 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt5035 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt5035 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt5060 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt5060 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt8707 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt8707 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt11726 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt11726 com.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt12859 res.......
# .......Training MLP_1_16 for 2018 SFO P1R p1rhs18_1247--p1rdt12859 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt942 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt942 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt1470 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt1470 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt1469 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt1469 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt104 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt1472 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs0_1247--p1udt1472 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs2_1247--p1udt813 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs2_1247--p1udt813 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs1_1247--p1udt716 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs1_1247--p1udt716 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs1_1247--p1udt1324 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs1_1247--p1udt1324 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs3_1247--p1udt1696 res.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs3_1247--p1udt1696 com.......
# .......Training MLP_1_16 for 2018 SFO P1U p1uhs3_1247--p1udt1824 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs11_1247--p2udt2578 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs11_1247--p2udt2578 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs11_1247--p2udt1836 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs11_1247--p2udt1836 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs11_1247--p2udt65 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs11_1247--p2udt65 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs7_1247--p2udt5977 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs7_1247--p2udt5977 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs7_1247--p2udt9294 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs7_1247--p2udt9294 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs7_1247--p2udt5979 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs7_1247--p2udt5979 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs9_1247--p2udt9130 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs9_1247--p2udt9130 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs9_1247--p2udt12222 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs9_1247--p2udt12222 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs9_1247--p2udt12221 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs9_1247--p2udt12221 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2udt3761 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2udt3761 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2umv84 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2umv84 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2udt6290 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2udt6290 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2udt3749 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs2_1247--p2udt3749 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs8_1247--p2udt11805 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs8_1247--p2udt611 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs8_1247--p2udt611 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs8_1247--p2udt8511 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs8_1247--p2udt8511 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt7578 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt7578 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt2367 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt2367 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt3280 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt3280 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt7563 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt7563 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt7341 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs4_1247--p2udt7341 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2udt4978 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2udt4978 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2udt10604 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2udt10604 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv29 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv29 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv96 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv96 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv119 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv119 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2udt10645 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv12 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs1_1247--p2umv12 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt11122 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt11122 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt10291 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt10291 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt9982 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt9982 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt9967 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt9967 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt10319 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs6_1247--p2udt10319 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs14_1247--p2udt9594 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs14_1247--p2udt9594 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs14_1247--p2udt7304 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs14_1247--p2udt7304 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs14_1247--p2udt7299 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs14_1247--p2udt7299 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs3_1247--p2udt9325 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs3_1247--p2udt9325 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs3_1247--p2udt6694 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs3_1247--p2udt6694 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs3_1247--p2udt1940 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs3_1247--p2udt1940 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs12_1247--p2udt4058 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs12_1247--p2udt4058 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs12_1247--p2udt4039 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs12_1247--p2udt4039 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs12_1247--p2udt5467 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs12_1247--p2udt5467 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs0_1247--p2udt1000 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs0_1247--p2udt1000 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs0_1247--p2udt12281 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs0_1247--p2udt12281 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs5_1247--p2udt2387 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs5_1247--p2udt2387 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs5_1247--p2udt2395 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs5_1247--p2udt2395 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs5_1247--p2udt799 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs5_1247--p2udt799 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10833 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10833 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10083 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10083 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10072 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10072 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10077 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs10_1247--p2udt10077 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt5108 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt5108 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt8612 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt8612 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt8610 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt8610 com.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt8073 res.......
# .......Training MLP_1_16 for 2018 SFO P2U p2uhs13_1247--p2udt8073 com.......
# All models, scalers, and results saved successfully!
# Runtime for Training models: 6.85 minutes

# %% [markdown]
# ___

# %% [markdown]
# ### Testing MLP-PSO

# %%
dataframe = loaded_input_data_dict[('2018', 'GSO', 'rural', 'regional', 'res')]
feature_columns = config['X_columns_D']
target_column = config['Y_column']

import numpy as np
import pandas as pd
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor as MLP
from sklearn.metrics import r2_score
import pyswarms as ps


def stratified_temperature_split(X, y, num_bins, test_size, random_state):
    """
    Perform stratified sampling based on temperature bins to ensure 
    that the temperature distribution in the training and test sets is consistent.
    """
    if not isinstance(X.index, pd.DatetimeIndex):
        raise ValueError("The DataFrame index must be a DatetimeIndex")
    
    temperature = X["Dry Bulb Temperature [°C]"]
    X["temp_bin"] = pd.qcut(temperature, q=num_bins, labels=False, duplicates="drop")
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, stratify=X["temp_bin"], random_state=random_state
    )
    
    X_train = X_train.drop(columns=["temp_bin"])
    X_test = X_test.drop(columns=["temp_bin"])
    
    return X_train, X_test, y_train, y_test


def train_mlp_model(X_train, y_train, X_test, y_test, layers, alpha):
    """
    Train an MLP model with the given architecture.
    """
    xnorm = MinMaxScaler().fit(X_train)
    X_train_norm = xnorm.transform(X_train)
    X_test_norm = xnorm.transform(X_test)
    
    ynorm = MinMaxScaler().fit(y_train)
    y_train_norm = ynorm.transform(y_train)
    
    mlp_model = MLP(activation='relu', hidden_layer_sizes=tuple(layers), learning_rate='constant', max_iter=500,
                     solver='adam', random_state=42)
    mlp_model.fit(X_train_norm, y_train_norm)
    
    y_test_pred_norm = mlp_model.predict(X_test_norm).reshape(-1, 1)
    y_test_pred = ynorm.inverse_transform(y_test_pred_norm)
    
    # Compute R2 score
    r2 = r2_score(y_test, y_test_pred)
    
    # Compute peak-related metrics
    max_y_test = np.max(y_test)  # Max actual value
    max_model_pred = np.max(y_test_pred)  # Max predicted value
    
    # Ratio difference between max predicted and max actual
    peak_load_error = ((max_y_test - max_model_pred) / max_y_test)
    
    # Compute objective function
    objective_value = alpha * r2 + (1 - alpha) * peak_load_error
    
    return objective_value


def objective_function(solutions, X_train, y_train, X_test, y_test, alpha):
    """
    Objective function for optimization, minimizing the linear combination of R2 and peak_load_error.
    """
    costs = []
    for solution in solutions:
        layers = [max(1, int(round(neurons))) for neurons in solution]
        if not layers:
            costs.append(float("inf"))  # Prevent empty layers
    
        else:
            costs.append(train_mlp_model(X_train, y_train, X_test, y_test, layers, alpha))
    return np.array(costs)


def optimize_mlp_architecture(X_train, y_train, X_test, y_test, alpha, num_agents=10, num_iterations=50):
    """
    Optimize MLP architecture using a PSOGWO hybrid approach.
    """
    def fitness_function(solution):
        return objective_function(solution, X_train, y_train, X_test, y_test, alpha)
    
    lb = [5] * 3  # Lower bound: at least 5 neurons per layer
    ub = [100] * 3  # Upper bound: max 100 neurons per layer, up to 3 layers
    
    problem = {
        "fit_func": fitness_function,
        "bounds": (lb, ub),
        "ub": ub,
        "minmax": "min",  # Optimization direction (minimization)
        "log_to": None
    }
    
    # PSO phase
    pso = ps.single.GlobalBestPSO(n_particles=num_agents, dimensions=len(lb), options={'c1': 2.05, 'c2': 2.05, 'w': 0.729})
    best_pso_solution, best_objective_value = pso.optimize(fitness_function, iters=num_iterations)
    
    best_pso_solution = np.atleast_1d(best_pso_solution)  # Ensure it's an array
    return [int(round(neurons)) for neurons in best_pso_solution if neurons > 0], best_objective_value


def main_pipeline(input_df, X_columns, Y_column, alpha=0.5):
    """
    Main function to train and optimize an MLP model.
    """
    X = input_df[X_columns]
    y = input_df[[Y_column]]
    X_train, X_test, y_train, y_test = stratified_temperature_split(X, y, num_bins=10, test_size=0.2, random_state=123)
    
    best_layers, best_objective_value = optimize_mlp_architecture(X_train, y_train, X_test, y_test, alpha)
    final_mlp_model = MLP(activation='relu', hidden_layer_sizes=tuple(best_layers), learning_rate='constant',
                           max_iter=500, solver='adam', random_state=42)
    
    xnorm = MinMaxScaler().fit(X_train)
    X_train_norm = xnorm.transform(X_train)
    X_test_norm = xnorm.transform(X_test)
    
    ynorm = MinMaxScaler().fit(y_train)
    y_train_norm = ynorm.transform(y_train)
    
    final_mlp_model.fit(X_train_norm, y_train_norm)
    y_test_pred_norm = final_mlp_model.predict(X_test_norm).reshape(-1, 1)
    y_test_pred = ynorm.inverse_transform(y_test_pred_norm)
    
    return final_mlp_model, best_layers, best_objective_value, y_test.values.flatten().tolist(), y_test_pred.flatten().tolist()

# Example Usage:
# final_model, best_architecture, objective_value, y_true, y_pred = main_pipeline(dataframe, feature_columns, target_column, alpha=0.7)

# Example Usage:
final_model, best_architecture, objective_value, y_true, y_pred = main_pipeline(dataframe, feature_columns, target_column, alpha=0.7)
print(f'Best MLP Architecture found: {best_architecture}')
# Out:
# 2025-03-25 10:44:51,227 - pyswarms.single.global_best - INFO - Optimize for 50 iters with {'c1': 2.05, 'c2': 2.05, 'w': 0.729}
# pyswarms.single.global_best: 100%|██████████|50/50, best_cost=-0.533
# 2025-03-25 10:52:41,378 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -0.5329583629331774, best pos: [29.3133675   0.68456235  1.5987726 ]

# %% [markdown]
# ## Process smart-ds load and resstock weather data and prepare input data for regression model training
#
# 1. Import weather and load data
# 2. Aggregate load data
# 3. Save weather and load data in a dictionary

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pyarrow.parquet as pq
import joblib
import scipy
import pandas as pd
import time
import os
import re
import glob
from datetime import datetime, timedelta
import yaml
import pprint

from src import figure_ops
from src import input_ops
from src import model_ops

# %% [markdown]
# ### Load config file with scenarios and parameters

# %%
config_file_name = 'config1'; config_path = f"config/{config_file_name}.yaml"; config = input_ops.load_config(config_path)
# pprint.pprint(config, sort_dicts=False)

input_data_training_path = config['input_data_training_path']
smart_ds_years = config['smart_ds_years']
CITY_REGIONS_TO_RUN = config['CITY_REGIONS_TO_RUN']
aggregation_level = config['aggregation_level']
building_types = config['building_types']
start_month = config['start_month']
end_month = config['end_month']

# %% [markdown]
# ### Import, process and save input data

# %%
# Import, process and save load and weather data (run only once per dataset, e.g., run again if want to add new regions or years)
start_time = time.time()

# # Define dictionary to store results
input_data_dict = {}

# Loop through all city, region, year, and building type combinations
for smart_ds_year in smart_ds_years:
    for city, regions in CITY_REGIONS_TO_RUN.items():
        for region in regions:
            ### Import and process resstock weather data ###
            # Load weather file based on cty-reigon that matches ResStock county (FIPS) 
            match city:
                case 'SFO':
                    weather_file = f'G0600750_{smart_ds_year}.csv'  # San-Francisco county
                case 'AUS':
                    weather_file = f'G4800150_{smart_ds_year}.csv'  # Austin county
                case _:
                    weather_file = f'G3700810_{smart_ds_year}.csv'  # Greensboro Guilford county
            weather_data_path = f'/nfs/turbo/seas-mtcraig-climate/Aviad/OpenDSS/raw_data/resstock_weather/amy{smart_ds_year}/{city}/{weather_file}'
            weather_df = input_ops.import_resstock_weather_data(weather_data_path, start_month, end_month)
            
            ### Import and process smart-ds load data ###
            parquet_data_path = f'/nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/{smart_ds_year}/{city}/{region}/load_data' # path to parquet files
            region_directory = f"/nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/{smart_ds_year}/{city}/{region}/scenarios/base_timeseries/opendss/" # path to where feeder folders are
            # Create a list of load_models (regional / feeders / buildings)   
            match aggregation_level:
                case 'regional':
                    load_models = ['regional']
                case 'feeder':
                    # load_models = find_feeder_folders(region_directory) # list of feeders in the format of '/substation/feeder/'
                    load_models = input_ops.make_feeder_list(region_directory) # list of feeders
                case _: # building
                    load_models = sorted([f for f in os.listdir(parquet_data_path) if f.endswith(".parquet")]) # list of buildings in the format of 'building_name.parquet' 
            print(f'......Creating data frame for {smart_ds_year} {city} {region} ......')
            for load_model in load_models:
                for building_type in building_types:
                    print(f'......Creating data frame for {smart_ds_year} {city} {region} {load_model} {building_type}......')
                    match aggregation_level:
                        case 'regional':
                            loads_dss_paths = input_ops.find_folders_with_file(region_directory, "Loads.dss")
                            load_df = input_ops.aggregate_parquet_data(parquet_data_path, loads_dss_paths, building_type, aggregation_level, start_month, end_month)  # 'res' for residential | 'com' for commercial
                        case 'feeder':
                            feeder_path_name = input_ops.add_feeder_upper_folder(load_model)
                            feeder_path = f'/nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/{smart_ds_year}/{city}/{region}/scenarios/base_timeseries/opendss/{feeder_path_name}'
                            loads_dss_paths = [feeder_path]
                            load_df = input_ops.aggregate_parquet_data(parquet_data_path, loads_dss_paths, building_type, aggregation_level, start_month, end_month)  # 'res' for residential | 'com' for commercial
                        case _: # building
                            load_prefix = load_model.split('_')[0]
                            if load_prefix not in {'com', 'res'}:
                                continue
                            load_df = input_ops.get_parquet_load_data(parquet_data_path, load_model,start_month,end_month)
                    if load_df.empty:
                        print(f"load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.")
                        continue 
                    
#                     if aggregation_level == 'regional' or aggregation_level == 'feeder':
#                         if aggregation_level == 'feeder'
#                             feeder_path_name = input_ops.add_feeder_upper_folder(load_model)
#                             feeder_path = f'/nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/{smart_ds_year}/{city}/{region}/scenarios/base_timeseries/opendss/{feeder_path_name}/Loads.dss'
#                             loads_dss_paths = [feeder_path]
#                         else:
#                             loads_dss_paths = file_ops.find_folders_with_file(region_directory, "Loads.dss")
                        
#                         load_df = input_ops.aggregate_parquet_data(parquet_data_path, loads_dss_paths, building_type, aggregation_level, start_month, end_month)  # 'res' for residential | 'com' for commercial
#                         if load_df.empty:
#                             print(f"load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.")
#                             continue 
#                     else:
#                         load_prefix = load_model.split('_')[0]
#                         if load_prefix not in {'com', 'res'}:
#                             continue
#                         load_df = input_ops.get_parquet_load_data(parquet_data_path, load_model,start_month,end_month)

                    # Reset index in load df (since 'building_id' is set as an index and not date time as in weather df)
                    load_df = load_df.reset_index()
                    # Merge data
                    input_df = input_ops.merge_load_weather(load_df, weather_df)
                    input_df.rename(columns={'month_x': 'month'}, inplace=True)
                    # Store in dictionary with (year, city, region, load_model, building_type) as the key
                    input_data_dict[(smart_ds_year, city, region, load_model, building_type)] = input_df
            # Save dictionary of current region as joblib files
            if aggregation_level == 'building':
                input_data_region_dir = f'{input_data_training_path}/{city}/{region}/'
                if not os.path.exists(input_data_region_dir):
                    os.makedirs(input_data_region_dir, exist_ok=True)
                print(f'saving joblib for {city} {region}')
                joblib.dump(input_data_dict, os.path.join(input_data_region_dir, f"input_data_dict.joblib"))                  
                     
# Save dictionary of all regions as joblib files
if aggregation_level == 'regional' or aggregation_level == 'feeder':
    print('saving joblib for all regions')
    os.makedirs(input_data_training_path, exist_ok=True)     # Ensure the directory exists
    joblib.dump(input_data_dict, os.path.join(input_data_training_path, "input_data_dict.joblib")) # Save the file

end_time = time.time(); print(f"Runtime for loading data: {(end_time - start_time) / 60:.2f} minutes")
# Out:
# ......Creating data frame for 2018 GSO rural ......
# ......Creating data frame for 2018 GSO rural rhs2_1247--rdt1262 res......
# ......Creating data frame for 2018 GSO rural rhs2_1247--rdt1262 com......
# ......Creating data frame for 2018 GSO rural rhs2_1247--rdt1264 res......
# ......Creating data frame for 2018 GSO rural rhs2_1247--rdt1264 com......
# ......Creating data frame for 2018 GSO rural rhs0_1247--rdt1527 res......
# ......Creating data frame for 2018 GSO rural rhs0_1247--rdt1527 com......
# ......Creating data frame for 2018 GSO rural rhs0_1247--rdt1948 res......
# ......Creating data frame for 2018 GSO rural rhs0_1247--rdt1948 com......
# ......Creating data frame for 2018 GSO rural rhs0_1247--rdt1534 res......
# ......Creating data frame for 2018 GSO rural rhs0_1247--rdt1534 com......
# ......Creating data frame for 2018 GSO rural rhs1_1247--rdt137 res......
# ......Creating data frame for 2018 GSO rural rhs1_1247--rdt137 com......
# ......Creating data frame for 2018 GSO rural rhs3_1247--rdt2999 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/rural/scenarios/base_timeseries/opendss/rhs3_1247/rhs3_1247--rdt2999 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO rural rhs3_1247--rdt2999 com......
# ......Creating data frame for 2018 GSO rural rhs3_1247--rdt2705 res......
# ......Creating data frame for 2018 GSO rural rhs3_1247--rdt2705 com......
# ......Creating data frame for 2018 GSO industrial ......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt785 res......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt785 com......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt1106 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs2_1247/ihs2_1247--idt1106 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt1106 com......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt1380 res......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt1380 com......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt486 res......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt486 com......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt1528 res......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt1528 com......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt898 res......
# ......Creating data frame for 2018 GSO industrial ihs2_1247--idt898 com......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt275 res......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt275 com......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt194 res......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt194 com......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs4_1247/ihs4_1247--idt194 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt1592 res......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt1592 com......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt1687 res......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt1687 com......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt1682 res......
# ......Creating data frame for 2018 GSO industrial ihs4_1247--idt1682 com......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt620 res......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt620 com......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt605 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs0_1247/ihs0_1247--idt605 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt605 com......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt740 res......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt740 com......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt999 res......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt999 com......
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt629 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs0_1247/ihs0_1247--idt629 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs0_1247--idt629 com......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1289 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs1_1247/ihs1_1247--idt1289 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1289 com......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1210 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs1_1247/ihs1_1247--idt1210 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1210 com......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1439 res......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1439 com......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt670 res......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt670 com......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1478 res......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1478 com......
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1485 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs1_1247/ihs1_1247--idt1485 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs1_1247--idt1485 com......
# ......Creating data frame for 2018 GSO industrial ihs5_1247--idt627 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs5_1247/ihs5_1247--idt627 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs5_1247--idt627 com......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt226 res......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt226 com......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt1010 res......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt1010 com......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt893 res......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt893 com......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt960 res......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt960 com......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt1153 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/industrial/scenarios/base_timeseries/opendss/ihs3_1247/ihs3_1247--idt1153 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt1153 com......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt1334 res......
# ......Creating data frame for 2018 GSO industrial ihs3_1247--idt1334 com......
# ......Creating data frame for 2018 GSO urban-suburban ......
# ......Creating data frame for 2018 GSO urban-suburban uhs11_1247--udt8110 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs11_1247--udt8110 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs11_1247--p1umv22 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/urban-suburban/scenarios/base_timeseries/opendss/uhs11_1247/uhs11_1247--p1umv22 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO urban-suburban uhs11_1247--p1umv22 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs11_1247--udt7105 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs11_1247--udt7105 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs8_1247--udt12494 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs8_1247--udt12494 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs8_1247--udt7252 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs8_1247--udt7252 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs6_1247--udt10788 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs6_1247--udt10788 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs6_1247--udt9964 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs6_1247--udt9964 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs6_1247--udt6570 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs6_1247--udt6570 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt15482 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt15482 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt17650 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt17650 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt1278 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt1278 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt15805 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs12_1247--udt15805 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs1_1247--udt15926 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs1_1247--udt15926 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs1_1247--udt20176 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs1_1247--udt20176 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs3_1247--udt1582 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs3_1247--udt1582 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs3_1247--udt1571 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs3_1247--udt1571 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs3_1247--udt1567 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs3_1247--udt1567 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs14_1247--udt5493 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs14_1247--udt5493 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs14_1247--udt12226 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs14_1247--udt12226 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs14_1247--udt11665 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs14_1247--udt11665 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs16_1247--udt310 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs16_1247--udt310 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs16_1247--udt15512 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs16_1247--udt15512 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs13_1247--udt4015 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs13_1247--udt4015 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs13_1247--udt4819 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs13_1247--udt4819 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt14110 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt14110 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt16813 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt16813 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt11456 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt11456 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt2508 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt2508 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt13714 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/urban-suburban/scenarios/base_timeseries/opendss/uhs9_1247/uhs9_1247--udt13714 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO urban-suburban uhs9_1247--udt13714 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs0_1247--udt12274 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs0_1247--udt12274 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs0_1247--udt16115 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs0_1247--udt16115 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs0_1247--udt14717 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs0_1247--udt14717 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs15_1247--udt20824 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs15_1247--udt20824 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs15_1247--udt19670 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs15_1247--udt19670 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs2_1247--udt9312 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs2_1247--udt9312 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs2_1247--udt10746 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs2_1247--udt10746 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs2_1247--udt12473 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs2_1247--udt12473 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs19_1247--udt19872 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs19_1247--udt19872 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs19_1247--udt15839 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/GSO/urban-suburban/scenarios/base_timeseries/opendss/uhs19_1247/uhs19_1247--udt15839 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 GSO urban-suburban uhs19_1247--udt15839 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs10_1247--udt11713 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs10_1247--udt11713 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs10_1247--udt13528 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs10_1247--udt13528 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs10_1247--udt12084 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs10_1247--udt12084 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs7_1247--udt9675 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs7_1247--udt9675 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs7_1247--udt9662 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs7_1247--udt9662 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs7_1247--udt15849 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs7_1247--udt15849 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs20_1247--udt8894 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs20_1247--udt8894 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs20_1247--udt5173 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs20_1247--udt5173 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs20_1247--udt9897 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs20_1247--udt9897 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs18_1247--udt17294 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs18_1247--udt17294 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs18_1247--udt11616 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs18_1247--udt11616 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs18_1247--udt13374 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs18_1247--udt13374 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs17_1247--udt6592 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs17_1247--udt6592 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs17_1247--udt9551 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs17_1247--udt9551 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt159 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt159 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt20368 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt20368 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt19869 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt19869 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt18558 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs5_1247--udt18558 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--udt12982 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--udt12982 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--p1umv8 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--p1umv8 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--udt11389 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--udt11389 com......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--p1umv7 res......
# ......Creating data frame for 2018 GSO urban-suburban uhs4_1247--p1umv7 com......
# ......Creating data frame for 2018 AUS P1R ......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt8207 res......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt8207 com......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt2378 res......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt2378 com......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt8208 res......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt8208 com......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt2874 res......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt2874 com......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt3467 res......
# ......Creating data frame for 2018 AUS P1R p1rhs3_1247--p1rdt3467 com......
# ......Creating data frame for 2018 AUS P1R p1rhs6_1247--p1rdt6561 res......
# ......Creating data frame for 2018 AUS P1R p1rhs6_1247--p1rdt6561 com......
# ......Creating data frame for 2018 AUS P1R p1rhs6_1247--p1rdt476 res......
# ......Creating data frame for 2018 AUS P1R p1rhs6_1247--p1rdt476 com......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt3039 res......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt3039 com......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt4805 res......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt4805 com......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt3426 res......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt3426 com......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt1528 res......
# ......Creating data frame for 2018 AUS P1R p1rhs2_1247--p1rdt1528 com......
# ......Creating data frame for 2018 AUS P1R p1rhs0_1247--p1rdt6854 res......
# ......Creating data frame for 2018 AUS P1R p1rhs0_1247--p1rdt6854 com......
# ......Creating data frame for 2018 AUS P1R p1rhs0_1247--p1rdt5663 res......
# ......Creating data frame for 2018 AUS P1R p1rhs0_1247--p1rdt5663 com......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt5481 res......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt5481 com......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt2300 res......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt2300 com......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt5185 res......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt5185 com......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt6999 res......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt6999 com......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt5851 res......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt5851 com......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt4715 res......
# ......Creating data frame for 2018 AUS P1R p1rhs4_1247--p1rdt4715 com......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt2397 res......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt2397 com......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt5979 res......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt5979 com......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt6578 res......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt6578 com......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt6634 res......
# ......Creating data frame for 2018 AUS P1R p1rhs1_1247--p1rdt6634 com......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt8064 res......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt8064 com......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt1339 res......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt1339 com......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt7748 res......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt7748 com......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt7147 res......
# ......Creating data frame for 2018 AUS P1R p1rhs5_1247--p1rdt7147 com......
# ......Creating data frame for 2018 AUS P1R p1rhs7_1247--p1rdt1161 res......
# ......Creating data frame for 2018 AUS P1R p1rhs7_1247--p1rdt1161 com......
# ......Creating data frame for 2018 AUS P1R p1rhs7_1247--p1rdt7669 res......
# ......Creating data frame for 2018 AUS P1R p1rhs7_1247--p1rdt7669 com......
# ......Creating data frame for 2018 AUS P1R p1rhs7_1247--p1rdt1291 res......
# ......Creating data frame for 2018 AUS P1R p1rhs7_1247--p1rdt1291 com......
# ......Creating data frame for 2018 AUS P1U ......
# ......Creating data frame for 2018 AUS P1U p1uhs0_1247--p1udt12703 res......
# ......Creating data frame for 2018 AUS P1U p1uhs0_1247--p1udt12703 com......
# ......Creating data frame for 2018 AUS P1U p1uhs0_1247--p1udt22170 res......
# ......Creating data frame for 2018 AUS P1U p1uhs0_1247--p1udt22170 com......
# ......Creating data frame for 2018 AUS P1U p1uhs0_1247--p1udt2142 res......
# ......Creating data frame for 2018 AUS P1U p1uhs0_1247--p1udt2142 com......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt18369 res......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt18369 com......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt9621 res......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt9621 com......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt899 res......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt899 com......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt18962 res......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt18962 com......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt8846 res......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt8846 com......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt18580 res......
# ......Creating data frame for 2018 AUS P1U p1uhs2_1247--p1udt18580 com......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt16446 res......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt16446 com......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt10621 res......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt10621 com......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt2578 res......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt2578 com......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt1456 res......
# ......Creating data frame for 2018 AUS P1U p1uhs20_1247--p1udt1456 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt20692 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt20692 com......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs9_1247/p1uhs9_1247--p1udt20692 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt387 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt387 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt21523 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt21523 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt25123 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt25123 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt22325 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt22325 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt6854 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt6854 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt19234 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt19234 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt13121 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt13121 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt22357 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs9_1247/p1uhs9_1247--p1udt22357 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt22357 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt20546 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt20546 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt13187 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt13187 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt21819 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt21819 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt20362 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt20362 com......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt4409 res......
# ......Creating data frame for 2018 AUS P1U p1uhs9_1247--p1udt4409 com......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt6863 res......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt6863 com......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt24624 res......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt24624 com......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt20099 res......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt20099 com......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt24311 res......
# ......Creating data frame for 2018 AUS P1U p1uhs22_1247--p1udt24311 com......
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt21168 res......
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt21168 com......
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt6143 res......
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt6143 com......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs14_1247/p1uhs14_1247--p1udt6143 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt9467 res......
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt9467 com......
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt7899 res......
# ......Creating data frame for 2018 AUS P1U p1uhs14_1247--p1udt7899 com......
# ......Creating data frame for 2018 AUS P1U p1uhs15_1247--p1udt9658 res......
# ......Creating data frame for 2018 AUS P1U p1uhs15_1247--p1udt9658 com......
# ......Creating data frame for 2018 AUS P1U p1uhs15_1247--p1udt17622 res......
# ......Creating data frame for 2018 AUS P1U p1uhs15_1247--p1udt17622 com......
# ......Creating data frame for 2018 AUS P1U p1uhs15_1247--p1udt2795 res......
# ......Creating data frame for 2018 AUS P1U p1uhs15_1247--p1udt2795 com......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt10118 res......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt10118 com......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt8187 res......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt8187 com......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs13_1247/p1uhs13_1247--p1udt8187 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt3522 res......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt3522 com......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt21698 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs13_1247/p1uhs13_1247--p1udt21698 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt21698 com......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt12530 res......
# ......Creating data frame for 2018 AUS P1U p1uhs13_1247--p1udt12530 com......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt20878 res......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt20878 com......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt22980 res......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt22980 com......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt6120 res......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt6120 com......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt12591 res......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt12591 com......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt14394 res......
# ......Creating data frame for 2018 AUS P1U p1uhs10_1247--p1udt14394 com......
# ......Creating data frame for 2018 AUS P1U p1uhs18_1247--p1udt20846 res......
# ......Creating data frame for 2018 AUS P1U p1uhs18_1247--p1udt20846 com......
# ......Creating data frame for 2018 AUS P1U p1uhs18_1247--p1udt6910 res......
# ......Creating data frame for 2018 AUS P1U p1uhs18_1247--p1udt6910 com......
# ......Creating data frame for 2018 AUS P1U p1uhs18_1247--p1udt15617 res......
# ......Creating data frame for 2018 AUS P1U p1uhs18_1247--p1udt15617 com......
# ......Creating data frame for 2018 AUS P1U p1uhs11_1247--p1udt12111 res......
# ......Creating data frame for 2018 AUS P1U p1uhs11_1247--p1udt12111 com......
# ......Creating data frame for 2018 AUS P1U p1uhs11_1247--p1udt22445 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs11_1247/p1uhs11_1247--p1udt22445 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs11_1247--p1udt22445 com......
# ......Creating data frame for 2018 AUS P1U p1uhs11_1247--p1udt25287 res......
# ......Creating data frame for 2018 AUS P1U p1uhs11_1247--p1udt25287 com......
# ......Creating data frame for 2018 AUS P1U p1uhs1_1247--p1udt10929 res......
# ......Creating data frame for 2018 AUS P1U p1uhs1_1247--p1udt10929 com......
# ......Creating data frame for 2018 AUS P1U p1uhs1_1247--p1udt14149 res......
# ......Creating data frame for 2018 AUS P1U p1uhs1_1247--p1udt14149 com......
# ......Creating data frame for 2018 AUS P1U p1uhs1_1247--p1udt138 res......
# ......Creating data frame for 2018 AUS P1U p1uhs1_1247--p1udt138 com......
# ......Creating data frame for 2018 AUS P1U p1uhs3_1247--p1udt6119 res......
# ......Creating data frame for 2018 AUS P1U p1uhs3_1247--p1udt6119 com......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs3_1247/p1uhs3_1247--p1udt6119 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs3_1247--p1udt13260 res......
# ......Creating data frame for 2018 AUS P1U p1uhs3_1247--p1udt13260 com......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt5257 res......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt5257 com......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt20780 res......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt20780 com......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt11662 res......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt11662 com......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt16206 res......
# ......Creating data frame for 2018 AUS P1U p1uhs21_1247--p1udt16206 com......
# ......Creating data frame for 2018 AUS P1U p1uhs4_1247--p1udt21090 res......
# ......Creating data frame for 2018 AUS P1U p1uhs4_1247--p1udt21090 com......
# ......Creating data frame for 2018 AUS P1U p1uhs4_1247--p1udt7282 res......
# ......Creating data frame for 2018 AUS P1U p1uhs4_1247--p1udt7282 com......
# ......Creating data frame for 2018 AUS P1U p1uhs19_1247--p1udt17263 res......
# ......Creating data frame for 2018 AUS P1U p1uhs19_1247--p1udt17263 com......
# ......Creating data frame for 2018 AUS P1U p1uhs19_1247--p1udt14631 res......
# ......Creating data frame for 2018 AUS P1U p1uhs19_1247--p1udt14631 com......
# ......Creating data frame for 2018 AUS P1U p1uhs6_1247--p1udt322 res......
# ......Creating data frame for 2018 AUS P1U p1uhs6_1247--p1udt322 com......
# ......Creating data frame for 2018 AUS P1U p1uhs6_1247--p1udt14764 res......
# ......Creating data frame for 2018 AUS P1U p1uhs6_1247--p1udt14764 com......
# ......Creating data frame for 2018 AUS P1U p1uhs6_1247--p1udt7653 res......
# ......Creating data frame for 2018 AUS P1U p1uhs6_1247--p1udt7653 com......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs6_1247/p1uhs6_1247--p1udt7653 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs5_1247--p1udt19613 res......
# ......Creating data frame for 2018 AUS P1U p1uhs5_1247--p1udt19613 com......
# ......Creating data frame for 2018 AUS P1U p1uhs5_1247--p1udt13240 res......
# ......Creating data frame for 2018 AUS P1U p1uhs5_1247--p1udt13240 com......
# ......Creating data frame for 2018 AUS P1U p1uhs5_1247--p1udt21449 res......
# ......Creating data frame for 2018 AUS P1U p1uhs5_1247--p1udt21449 com......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt11006 res......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt11006 com......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt16473 res......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt16473 com......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt7988 res......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt7988 com......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt22164 res......
# ......Creating data frame for 2018 AUS P1U p1uhs16_1247--p1udt22164 com......
# ......Creating data frame for 2018 AUS P1U p1uhs8_1247--p1udt22258 res......
# ......Creating data frame for 2018 AUS P1U p1uhs8_1247--p1udt22258 com......
# ......Creating data frame for 2018 AUS P1U p1uhs8_1247--p1udt4671 res......
# ......Creating data frame for 2018 AUS P1U p1uhs8_1247--p1udt4671 com......
# ......Creating data frame for 2018 AUS P1U p1uhs8_1247--p1udt2544 res......
# ......Creating data frame for 2018 AUS P1U p1uhs8_1247--p1udt2544 com......
# ......Creating data frame for 2018 AUS P1U p1uhs23_1247--p1udt25139 res......
# ......Creating data frame for 2018 AUS P1U p1uhs23_1247--p1udt25139 com......
# ......Creating data frame for 2018 AUS P1U p1uhs23_1247--p1udt21301 res......
# ......Creating data frame for 2018 AUS P1U p1uhs23_1247--p1udt21301 com......
# ......Creating data frame for 2018 AUS P1U p1uhs7_1247--p1udt14301 res......
# ......Creating data frame for 2018 AUS P1U p1uhs7_1247--p1udt14301 com......
# ......Creating data frame for 2018 AUS P1U p1uhs7_1247--p1udt1702 res......
# ......Creating data frame for 2018 AUS P1U p1uhs7_1247--p1udt1702 com......
# ......Creating data frame for 2018 AUS P1U p1uhs17_1247--p1udt19976 res......
# ......Creating data frame for 2018 AUS P1U p1uhs17_1247--p1udt19976 com......
# ......Creating data frame for 2018 AUS P1U p1uhs17_1247--p1udt1947 res......
# ......Creating data frame for 2018 AUS P1U p1uhs17_1247--p1udt1947 com......
# ......Creating data frame for 2018 AUS P1U p1uhs17_1247--p1udt21587 res......
# ......Creating data frame for 2018 AUS P1U p1uhs17_1247--p1udt21587 com......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt8950 res......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt8950 com......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt11164 res......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt11164 com......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt23696 res......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt23696 com......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt8568 res......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt8568 com......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt14325 res......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt14325 com......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt23867 res......
# ......Creating data frame for 2018 AUS P1U p1uhs12_1247--p1udt23867 com......
# ......Creating data frame for 2018 AUS P1U p1uhs24_1247--p1umv22 res......
# ......Creating data frame for 2018 AUS P1U p1uhs24_1247--p1umv22 com......
# ......Creating data frame for 2018 AUS P1U p1uhs24_1247--p1umv26 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P1U/scenarios/base_timeseries/opendss/p1uhs24_1247/p1uhs24_1247--p1umv26 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P1U p1uhs24_1247--p1umv26 com......
# ......Creating data frame for 2018 AUS P2U ......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt5729 res......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt5729 com......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt7967 res......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt7967 com......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt4732 res......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt4732 com......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt3455 res......
# ......Creating data frame for 2018 AUS P2U p2uhs11_1247--p2udt3455 com......
# ......Creating data frame for 2018 AUS P2U p2uhs7_1247--p2udt2957 res......
# ......Creating data frame for 2018 AUS P2U p2uhs7_1247--p2udt2957 com......
# ......Creating data frame for 2018 AUS P2U p2uhs7_1247--p2udt3821 res......
# ......Creating data frame for 2018 AUS P2U p2uhs7_1247--p2udt3821 com......
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt5858 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P2U/scenarios/base_timeseries/opendss/p2uhs9_1247/p2uhs9_1247--p2udt5858 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt5858 com......
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt3884 res......
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt3884 com......
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt3330 res......
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt3330 com......
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt8056 res......
# ......Creating data frame for 2018 AUS P2U p2uhs9_1247--p2udt8056 com......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt8082 res......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt8082 com......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt7925 res......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt7925 com......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt8516 res......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt8516 com......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt106 res......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt106 com......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt8512 res......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt8512 com......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt3567 res......
# ......Creating data frame for 2018 AUS P2U p2uhs2_1247--p2udt3567 com......
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt6424 res......
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt6424 com......
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt6561 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/AUS/P2U/scenarios/base_timeseries/opendss/p2uhs8_1247/p2uhs8_1247--p2udt6561 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt6561 com......
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt5538 res......
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt5538 com......
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt4184 res......
# ......Creating data frame for 2018 AUS P2U p2uhs8_1247--p2udt4184 com......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt7573 res......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt7573 com......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt8180 res......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt8180 com......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt5265 res......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt5265 com......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt3496 res......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt3496 com......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt7735 res......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt7735 com......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt433 res......
# ......Creating data frame for 2018 AUS P2U p2uhs4_1247--p2udt433 com......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt3740 res......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt3740 com......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt4740 res......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt4740 com......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt3475 res......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt3475 com......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt7154 res......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt7154 com......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt3615 res......
# ......Creating data frame for 2018 AUS P2U p2uhs1_1247--p2udt3615 com......
# ...
# ......Creating data frame for 2018 SFO P1R p1rhs25_1247--p1rdt7510 res......
# ......Creating data frame for 2018 SFO P1R p1rhs25_1247--p1rdt7510 com......
# ......Creating data frame for 2018 SFO P1R p1rhs25_1247--p1rdt13798 res......
# ......Creating data frame for 2018 SFO P1R p1rhs25_1247--p1rdt13798 com......
# ......Creating data frame for 2018 SFO P1R p1rhs25_1247--p1rdt12732 res......
# ......Creating data frame for 2018 SFO P1R p1rhs25_1247--p1rdt12732 com......
# ......Creating data frame for 2018 SFO P1R p1rhs22_1247--p1rdt12023 res......
# ......Creating data frame for 2018 SFO P1R p1rhs22_1247--p1rdt12023 com......
# ......Creating data frame for 2018 SFO P1R p1rhs22_1247--p1rdt11230 res......
# ......Creating data frame for 2018 SFO P1R p1rhs22_1247--p1rdt11230 com......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt348 res......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt348 com......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt1011 res......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt1011 com......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt778 res......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt778 com......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt1224 res......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt1224 com......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt204 res......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt204 com......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt25 res......
# ......Creating data frame for 2018 SFO P1R p1rhs5_1247--p1rdt25 com......
# ......Creating data frame for 2018 SFO P1R p1rhs26_1247--p1rdt13367 res......
# ......Creating data frame for 2018 SFO P1R p1rhs26_1247--p1rdt13367 com......
# ......Creating data frame for 2018 SFO P1R p1rhs26_1247--p1rdt10569 res......
# ......Creating data frame for 2018 SFO P1R p1rhs26_1247--p1rdt10569 com......
# ......Creating data frame for 2018 SFO P1R p1rhs26_1247--p1rdt11700 res......
# ......Creating data frame for 2018 SFO P1R p1rhs26_1247--p1rdt11700 com......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt6488 res......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt6488 com......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt5342 res......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt5342 com......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt8583 res......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt8583 com......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt7711 res......
# ......Creating data frame for 2018 SFO P1R p1rhs7_1247--p1rdt7711 com......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/SFO/P1R/scenarios/base_timeseries/opendss/p1rhs7_1247/p1rhs7_1247--p1rdt7711 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 SFO P1R p1rhs16_1247--p1rdt3521 res......
# ......Creating data frame for 2018 SFO P1R p1rhs16_1247--p1rdt3521 com......
# ......Creating data frame for 2018 SFO P1R p1rhs9_1247--p1rdt592 res......
# ......Creating data frame for 2018 SFO P1R p1rhs9_1247--p1rdt592 com......
# ......Creating data frame for 2018 SFO P1R p1rhs9_1247--p1rdt610 res......
# ......Creating data frame for 2018 SFO P1R p1rhs9_1247--p1rdt610 com......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt11804 res......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt11804 com......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt11118 res......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt11118 com......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt5035 res......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt5035 com......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt5060 res......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt5060 com......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt8707 res......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt8707 com......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt11726 res......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt11726 com......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt12859 res......
# ......Creating data frame for 2018 SFO P1R p1rhs18_1247--p1rdt12859 com......
# ......Creating data frame for 2018 SFO P1U ......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt942 res......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt942 com......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt1470 res......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt1470 com......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt1469 res......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt1469 com......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt104 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/SFO/P1U/scenarios/base_timeseries/opendss/p1uhs0_1247/p1uhs0_1247--p1udt104 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt104 com......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt1472 res......
# ......Creating data frame for 2018 SFO P1U p1uhs0_1247--p1udt1472 com......
# ......Creating data frame for 2018 SFO P1U p1uhs2_1247--p1udt813 res......
# ......Creating data frame for 2018 SFO P1U p1uhs2_1247--p1udt813 com......
# ......Creating data frame for 2018 SFO P1U p1uhs1_1247--p1udt716 res......
# ......Creating data frame for 2018 SFO P1U p1uhs1_1247--p1udt716 com......
# ......Creating data frame for 2018 SFO P1U p1uhs1_1247--p1udt1324 res......
# ......Creating data frame for 2018 SFO P1U p1uhs1_1247--p1udt1324 com......
# ......Creating data frame for 2018 SFO P1U p1uhs3_1247--p1udt1696 res......
# ......Creating data frame for 2018 SFO P1U p1uhs3_1247--p1udt1696 com......
# ......Creating data frame for 2018 SFO P1U p1uhs3_1247--p1udt1824 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/SFO/P1U/scenarios/base_timeseries/opendss/p1uhs3_1247/p1uhs3_1247--p1udt1824 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 SFO P1U p1uhs3_1247--p1udt1824 com......
# ......Creating data frame for 2018 SFO P2U ......
# ......Creating data frame for 2018 SFO P2U p2uhs11_1247--p2udt2578 res......
# ......Creating data frame for 2018 SFO P2U p2uhs11_1247--p2udt2578 com......
# ......Creating data frame for 2018 SFO P2U p2uhs11_1247--p2udt1836 res......
# ......Creating data frame for 2018 SFO P2U p2uhs11_1247--p2udt1836 com......
# ......Creating data frame for 2018 SFO P2U p2uhs11_1247--p2udt65 res......
# ......Creating data frame for 2018 SFO P2U p2uhs11_1247--p2udt65 com......
# ......Creating data frame for 2018 SFO P2U p2uhs7_1247--p2udt5977 res......
# ......Creating data frame for 2018 SFO P2U p2uhs7_1247--p2udt5977 com......
# ......Creating data frame for 2018 SFO P2U p2uhs7_1247--p2udt9294 res......
# ......Creating data frame for 2018 SFO P2U p2uhs7_1247--p2udt9294 com......
# ......Creating data frame for 2018 SFO P2U p2uhs7_1247--p2udt5979 res......
# ......Creating data frame for 2018 SFO P2U p2uhs7_1247--p2udt5979 com......
# ......Creating data frame for 2018 SFO P2U p2uhs9_1247--p2udt9130 res......
# ......Creating data frame for 2018 SFO P2U p2uhs9_1247--p2udt9130 com......
# ......Creating data frame for 2018 SFO P2U p2uhs9_1247--p2udt12222 res......
# ......Creating data frame for 2018 SFO P2U p2uhs9_1247--p2udt12222 com......
# ......Creating data frame for 2018 SFO P2U p2uhs9_1247--p2udt12221 res......
# ......Creating data frame for 2018 SFO P2U p2uhs9_1247--p2udt12221 com......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2udt3761 res......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2udt3761 com......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2umv84 res......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2umv84 com......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2udt6290 res......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2udt6290 com......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2udt3749 res......
# ......Creating data frame for 2018 SFO P2U p2uhs2_1247--p2udt3749 com......
# ......Creating data frame for 2018 SFO P2U p2uhs8_1247--p2udt11805 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/SFO/P2U/scenarios/base_timeseries/opendss/p2uhs8_1247/p2uhs8_1247--p2udt11805 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 SFO P2U p2uhs8_1247--p2udt11805 com......
# ......Creating data frame for 2018 SFO P2U p2uhs8_1247--p2udt611 res......
# ......Creating data frame for 2018 SFO P2U p2uhs8_1247--p2udt611 com......
# ......Creating data frame for 2018 SFO P2U p2uhs8_1247--p2udt8511 res......
# ......Creating data frame for 2018 SFO P2U p2uhs8_1247--p2udt8511 com......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt7578 res......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt7578 com......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt2367 res......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt2367 com......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt3280 res......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt3280 com......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt7563 res......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt7563 com......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt7341 res......
# ......Creating data frame for 2018 SFO P2U p2uhs4_1247--p2udt7341 com......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2udt4978 res......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2udt4978 com......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2udt10604 res......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2udt10604 com......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv29 res......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv29 com......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv96 res......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv96 com......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv119 res......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv119 com......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2udt10645 res......
# Feeder /nfs/turbo/seas-mtcraig-climate/SMART-DS/v1.0/2018/SFO/P2U/scenarios/base_timeseries/opendss/p2uhs1_1247/p2uhs1_1247--p2udt10645 skipped since no parquet files found in the given folder with the specified prefix.
# load_df is empty, perhaps parquet files were not found in the given folder with the specified prefix.
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2udt10645 com......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv12 res......
# ......Creating data frame for 2018 SFO P2U p2uhs1_1247--p2umv12 com......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt11122 res......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt11122 com......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt10291 res......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt10291 com......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt9982 res......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt9982 com......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt9967 res......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt9967 com......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt10319 res......
# ......Creating data frame for 2018 SFO P2U p2uhs6_1247--p2udt10319 com......
# ......Creating data frame for 2018 SFO P2U p2uhs14_1247--p2udt9594 res......
# ......Creating data frame for 2018 SFO P2U p2uhs14_1247--p2udt9594 com......
# ......Creating data frame for 2018 SFO P2U p2uhs14_1247--p2udt7304 res......
# ......Creating data frame for 2018 SFO P2U p2uhs14_1247--p2udt7304 com......
# ......Creating data frame for 2018 SFO P2U p2uhs14_1247--p2udt7299 res......
# ......Creating data frame for 2018 SFO P2U p2uhs14_1247--p2udt7299 com......
# ......Creating data frame for 2018 SFO P2U p2uhs3_1247--p2udt9325 res......
# ......Creating data frame for 2018 SFO P2U p2uhs3_1247--p2udt9325 com......
# ......Creating data frame for 2018 SFO P2U p2uhs3_1247--p2udt6694 res......
# ......Creating data frame for 2018 SFO P2U p2uhs3_1247--p2udt6694 com......
# ......Creating data frame for 2018 SFO P2U p2uhs3_1247--p2udt1940 res......
# ......Creating data frame for 2018 SFO P2U p2uhs3_1247--p2udt1940 com......
# ......Creating data frame for 2018 SFO P2U p2uhs12_1247--p2udt4058 res......
# ......Creating data frame for 2018 SFO P2U p2uhs12_1247--p2udt4058 com......
# ......Creating data frame for 2018 SFO P2U p2uhs12_1247--p2udt4039 res......
# ......Creating data frame for 2018 SFO P2U p2uhs12_1247--p2udt4039 com......
# ......Creating data frame for 2018 SFO P2U p2uhs12_1247--p2udt5467 res......
# ......Creating data frame for 2018 SFO P2U p2uhs12_1247--p2udt5467 com......
# ......Creating data frame for 2018 SFO P2U p2uhs0_1247--p2udt1000 res......
# ......Creating data frame for 2018 SFO P2U p2uhs0_1247--p2udt1000 com......
# ......Creating data frame for 2018 SFO P2U p2uhs0_1247--p2udt12281 res......
# ......Creating data frame for 2018 SFO P2U p2uhs0_1247--p2udt12281 com......
# ......Creating data frame for 2018 SFO P2U p2uhs5_1247--p2udt2387 res......
# ......Creating data frame for 2018 SFO P2U p2uhs5_1247--p2udt2387 com......
# ......Creating data frame for 2018 SFO P2U p2uhs5_1247--p2udt2395 res......
# ......Creating data frame for 2018 SFO P2U p2uhs5_1247--p2udt2395 com......
# ......Creating data frame for 2018 SFO P2U p2uhs5_1247--p2udt799 res......
# ......Creating data frame for 2018 SFO P2U p2uhs5_1247--p2udt799 com......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10833 res......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10833 com......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10083 res......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10083 com......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10072 res......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10072 com......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10077 res......
# ......Creating data frame for 2018 SFO P2U p2uhs10_1247--p2udt10077 com......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt5108 res......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt5108 com......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt8612 res......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt8612 com......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt8610 res......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt8610 com......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt8073 res......
# ......Creating data frame for 2018 SFO P2U p2uhs13_1247--p2udt8073 com......
# saving joblib for all regions
# Runtime for loading data: 61.07 minutes
